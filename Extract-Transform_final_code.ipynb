# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)

backers = pd.read_csv('backer_info.csv')
backers
# Out:
#                                                                                              backer_info
# 0           {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1           {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2             {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3     {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4                  {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# ...                                                                                                  ...
# 8170     {"backer_id": "st581", "cf_id": 65, "name": "Serita Thebault", "email": "sthebault@yandex.com"}
# 8171    {"backer_id": "gf637", "cf_id": 563, "name": "Glenn Foerstner", "email": "gfoerstner@yahoo.com"}
# 8172        {"backer_id": "rc983", "cf_id": 1114, "name": "Robt Collin", "email": "rcollin@outlook.com"}
# 8173          {"backer_id": "cz381", "cf_id": 65, "name": "Corina Zappa", "email": "czappa@outlook.com"}
# 8174         {"backer_id": "fg535", "cf_id": 65, "name": "Freeman Gibbs", "email": "fgibbs@outlook.com"}
#
# [8175 rows x 1 columns]

# %%
# Iterate through the backers DataFrame and convert each row to a dictionary.
# Iterate through each dictionary (row) and get the values for each row using list comprehension.
# Append the list of values for each row to a list. 

#json.loads reads the string in as a dictionary, so we use it for ease
backers_rows = [json.loads(row['backer_info']) for i, row in backers.iterrows()]


# Print out the list of values for each row.
backers_rows
# Out:
# [{'backer_id': 'av166',
#   'cf_id': 968,
#   'name': 'Angelo Vincent',
#   'email': 'avincent@live.com'},
#  {'backer_id': 'ha127',
#   'cf_id': 563,
#   'name': 'Hubert Arnold',
#   'email': 'harnold@yandex.com'},
#  {'backer_id': 'lg794',
#   'cf_id': 65,
#   'name': 'Loris Goulet',
#   'email': 'lgoulet@yandex.com'},
#  {'backer_id': 'tb566',
#   'cf_id': 563,
#   'name': 'Teodora Brunelli',
#   'email': 'tbrunelli@outlook.com'},
#  {'backer_id': 'lh506',
#   'cf_id': 563,
#   'name': 'Lexie Hunt',
#   'email': 'lhunt@live.com'},
#  {'backer_id': 'lh382',
#   'cf_id': 563,
#   'name': 'Lambert Huber',
#   'email': 'lhuber@live.com'},
#  {'backer_id': 'em444',
#   'cf_id': 563,
#   'name': 'Emmy Morin',
#   'email': 'emorin@live.com'},
#  {'backer_id': 'at582',
#   'cf_id': 1572,
#   'name': 'Armonda Trani',
#   'email': 'atrani@live.com'},
#  {'backer_id': 'id772',
#   'cf_id': 1911,
#   'name': 'Ilana Duke',
#   'email': 'iduke@outlook.com'},
#  {'backer_id': 'lw275',
#   'cf_id': 65,
#   'name': 'Leigha Wright',
#   'email': 'lwright@live.com'},
#  {'backer_id': 'ub509',
#   'cf_id': 65,
#   'name': 'Uwe Becker',
#   'email': 'ubecker@yahoo.com'},
#  {'backer_id': 'ha915',
#   'cf_id': 1572,
#   'name': 'Hawa Audy',
#   'email': 'haudy@gmail.com'},
#  {'backer_id': 'bb881',
#   'cf_id': 968,
#   'name': 'Bia Bonura',
#   'email': 'bbonura@yahoo.com'},
#  {'backer_id': 'mg332',
#   'cf_id': 65,
#   'name': 'Michel Garner',
#   'email': 'mgarner@protonmail.com'},
#  {'backer_id': 'kd700',
#   'cf_id': 1572,
#   'name': 'Karole Dunn',
#   'email': 'kdunn@yahoo.com'},
#  {'backer_id': 'as695',
#   'cf_id': 563,
#   'name': 'Arndt Schreiber',
#   'email': 'aschreiber@yahoo.com'},
#  {'backer_id': 'iv513',
#   'cf_id': 65,
#   'name': 'Imen Villeneuve',
#   'email': 'ivilleneuve@yahoo.com'},
#  {'backer_id': 'ab842',
#   'cf_id': 65,
#   'name': 'Alcina Bonadonna',
#   'email': 'abonadonna@yandex.com'},
#  {'backer_id': 're181',
#   'cf_id': 1114,
#   'name': 'Raelene Espinoza',
#   'email': 'respinoza@outlook.com'},
#  {'backer_id': 'kn133',
#   'cf_id': 65,
#   'name': 'Kati Nash',
#   'email': 'knash@protonmail.com'},
#  {'backer_id': 'gj893',
#   'cf_id': 65,
#   'name': 'Georg Jager',
#   'email': 'gjager@yahoo.com'},
#  {'backer_id': 'vp915',
#   'cf_id': 948,
#   'name': 'Virgilio Paolella',
#   'email': 'vpaolella@gmail.com'},
#  {'backer_id': 'ja995',
#   'cf_id': 563,
#   'name': 'Jerrica Avila',
#   'email': 'javila@protonmail.com'},
#  {'backer_id': 'ga249',
#   'cf_id': 563,
#   'name': 'Gianni Achterberg',
#   'email': 'gachterberg@live.com'},
#  {'backer_id': 'td403',
#   'cf_id': 65,
#   'name': 'Timoteo Dion',
#   'email': 'tdion@gmail.com'},
#  {'backer_id': 'tv463',
#   'cf_id': 1572,
#   'name': 'Teodoro Verno',
#   'email': 'tverno@yandex.com'},
#  {'backer_id': 'mw606',
#   'cf_id': 65,
#   'name': 'Morris Waller',
#   'email': 'mwaller@protonmail.com'},
#  {'backer_id': 'hc648',
#   'cf_id': 65,
#   'name': 'Hans Chen',
#   'email': 'hchen@yandex.com'},
#  {'backer_id': 'ta379',
#   'cf_id': 563,
#   'name': 'Trilby Auer',
#   'email': 'tauer@yahoo.com'},
#  {'backer_id': 'tj583',
#   'cf_id': 1572,
#   'name': 'Theola Jodoin',
#   'email': 'tjodoin@yandex.com'},
#  {'backer_id': 'tc559',
#   'cf_id': 65,
#   'name': 'Tova Capri',
#   'email': 'tcapri@live.com'},
#  {'backer_id': 'ww629',
#   'cf_id': 65,
#   'name': 'Wanda Walton',
#   'email': 'wwalton@protonmail.com'},
#  {'backer_id': 'jg155',
#   'cf_id': 1572,
#   'name': 'Justine Gill',
#   'email': 'jgill@yahoo.com'},
#  {'backer_id': 'jd328',
#   'cf_id': 1911,
#   'name': 'Julee Doyle',
#   'email': 'jdoyle@gmail.com'},
#  {'backer_id': 'ld239',
#   'cf_id': 65,
#   'name': 'Lisbeth Deliso',
#   'email': 'ldeliso@gmail.com'},
#  {'backer_id': 'cv918',
#   'cf_id': 968,
#   'name': 'Carl Valdez',
#   'email': 'cvaldez@gmail.com'},
#  {'backer_id': 'kb145',
#   'cf_id': 563,
#   'name': 'Kelyan Butler',
#   'email': 'kbutler@yahoo.com'},
#  {'backer_id': 'dw578',
#   'cf_id': 65,
#   'name': 'Donat Weber',
#   'email': 'dweber@live.com'},
#  {'backer_id': 'ad511',
#   'cf_id': 65,
#   'name': 'Alethia Delorme',
#   'email': 'adelorme@outlook.com'},
#  {'backer_id': 'db633',
#   'cf_id': 65,
#   'name': 'Darrell Bernardi',
#   'email': 'dbernardi@yandex.com'},
#  {'backer_id': 'cr369',
#   'cf_id': 65,
#   'name': 'Carina Reeves',
#   'email': 'creeves@gmail.com'},
#  {'backer_id': 'mr978',
#   'cf_id': 65,
#   'name': 'Marvin Ruiz',
#   'email': 'mruiz@outlook.com'},
#  {'backer_id': 'md167',
#   'cf_id': 1572,
#   'name': 'Mariabella Duerr',
#   'email': 'mduerr@live.com'},
#  {'backer_id': 'jr877',
#   'cf_id': 1572,
#   'name': 'Jeni Ricco',
#   'email': 'jricco@live.com'},
#  {'backer_id': 'om753',
#   'cf_id': 65,
#   'name': 'Otto Munoz',
#   'email': 'omunoz@yahoo.com'},
#  {'backer_id': 'ng231',
#   'cf_id': 1114,
#   'name': 'Nesrine Gensch',
#   'email': 'ngensch@yandex.com'},
#  {'backer_id': 'tl316',
#   'cf_id': 65,
#   'name': 'Tullio Lejeune',
#   'email': 'tlejeune@outlook.com'},
#  {'backer_id': 'dl139',
#   'cf_id': 563,
#   'name': 'Dreama Lonardo',
#   'email': 'dlonardo@live.com'},
#  {'backer_id': 'mw253',
#   'cf_id': 968,
#   'name': 'Maryrose West',
#   'email': 'mwest@live.com'},
#  {'backer_id': 'im424',
#   'cf_id': 65,
#   'name': 'Irina Mays',
#   'email': 'imays@yandex.com'},
#  {'backer_id': 'mb131',
#   'cf_id': 968,
#   'name': 'Marcelo Brose',
#   'email': 'mbrose@protonmail.com'},
#  {'backer_id': 'nc240',
#   'cf_id': 1572,
#   'name': 'Nestor Coutant',
#   'email': 'ncoutant@gmail.com'},
#  {'backer_id': 'ab318',
#   'cf_id': 1572,
#   'name': 'Aloysius Braun',
#   'email': 'abraun@live.com'},
#  {'backer_id': 'af301',
#   'cf_id': 65,
#   'name': 'Amos Ferre',
#   'email': 'aferre@gmail.com'},
#  {'backer_id': 'bl736',
#   'cf_id': 563,
#   'name': 'Brigitte Lynch',
#   'email': 'blynch@outlook.com'},
#  {'backer_id': 'ar957',
#   'cf_id': 65,
#   'name': 'Alegra Ramsey',
#   'email': 'aramsey@yahoo.com'},
#  {'backer_id': 'cb474',
#   'cf_id': 968,
#   'name': 'Conchita Beitel',
#   'email': 'cbeitel@gmail.com'},
#  {'backer_id': 'dv246',
#   'cf_id': 1572,
#   'name': 'Donnie Vernet',
#   'email': 'dvernet@protonmail.com'},
#  {'backer_id': 'cj111',
#   'cf_id': 563,
#   'name': 'Cyril Jones',
#   'email': 'cjones@protonmail.com'},
#  {'backer_id': 'lh765',
#   'cf_id': 563,
#   'name': 'Lucinda Hays',
#   'email': 'lhays@outlook.com'},
#  {'backer_id': 'wh697',
#   'cf_id': 65,
#   'name': 'Walter Hermann',
#   'email': 'whermann@outlook.com'},
#  {'backer_id': 'eb714',
#   'cf_id': 65,
#   'name': 'Emil Blanc',
#   'email': 'eblanc@protonmail.com'},
#  {'backer_id': 'ec356',
#   'cf_id': 1572,
#   'name': 'Eldwin Cesare',
#   'email': 'ecesare@protonmail.com'},
#  {'backer_id': 'yh129',
#   'cf_id': 65,
#   'name': 'Yusuf Hudson',
#   'email': 'yhudson@protonmail.com'},
#  {'backer_id': 'as494',
#   'cf_id': 65,
#   'name': 'Arrigo Salazar',
#   'email': 'asalazar@gmail.com'},
#  {'backer_id': 'lb146',
#   'cf_id': 563,
#   'name': 'Levi Beck',
#   'email': 'lbeck@gmail.com'},
#  {'backer_id': 'cc470',
#   'cf_id': 563,
#   'name': 'Celinda Caillet',
#   'email': 'ccaillet@yandex.com'},
#  {'backer_id': 'mm239',
#   'cf_id': 563,
#   'name': 'Marcus Medici',
#   'email': 'mmedici@gmail.com'},
#  {'backer_id': 'dg360',
#   'cf_id': 65,
#   'name': 'Daysi Gamble',
#   'email': 'dgamble@yahoo.com'},
#  {'backer_id': 'rh399',
#   'cf_id': 1572,
#   'name': 'Rory Hildebrand',
#   'email': 'rhildebrand@yahoo.com'},
#  {'backer_id': 'hr430',
#   'cf_id': 65,
#   'name': 'Heini Raffin',
#   'email': 'hraffin@yahoo.com'},
#  {'backer_id': 'ar829',
#   'cf_id': 65,
#   'name': 'Anna Randall',
#   'email': 'arandall@outlook.com'},
#  {'backer_id': 'sw301',
#   'cf_id': 65,
#   'name': 'Sharmaine Weber',
#   'email': 'sweber@yahoo.com'},
#  {'backer_id': 'rr355',
#   'cf_id': 65,
#   'name': 'Ranee Renault',
#   'email': 'rrenault@outlook.com'},
#  {'backer_id': 'zc515',
#   'cf_id': 1572,
#   'name': 'Zak Cianciola',
#   'email': 'zcianciola@yahoo.com'},
#  {'backer_id': 'gp101',
#   'cf_id': 65,
#   'name': 'Granville Potts',
#   'email': 'gpotts@gmail.com'},
#  {'backer_id': 'bm741',
#   'cf_id': 65,
#   'name': 'Bo Marsh',
#   'email': 'bmarsh@live.com'},
#  {'backer_id': 'jd148',
#   'cf_id': 65,
#   'name': 'Jay Duerr',
#   'email': 'jduerr@yahoo.com'},
#  {'backer_id': 'mm632',
#   'cf_id': 65,
#   'name': 'Milla Morin',
#   'email': 'mmorin@yahoo.com'},
#  {'backer_id': 'ls884',
#   'cf_id': 65,
#   'name': 'Leanne Savage',
#   'email': 'lsavage@gmail.com'},
#  {'backer_id': 'sp364',
#   'cf_id': 968,
#   'name': 'Silvana Patton',
#   'email': 'spatton@live.com'},
#  {'backer_id': 'hh963',
#   'cf_id': 65,
#   'name': 'Harvey Hoch',
#   'email': 'hhoch@outlook.com'},
#  {'backer_id': 'sb272',
#   'cf_id': 65,
#   'name': 'Seth Berthier',
#   'email': 'sberthier@protonmail.com'},
#  {'backer_id': 'et566',
#   'cf_id': 1114,
#   'name': 'Eugen Trani',
#   'email': 'etrani@protonmail.com'},
#  {'backer_id': 'sd421',
#   'cf_id': 1572,
#   'name': 'Santina Dieter',
#   'email': 'sdieter@yahoo.com'},
#  {'backer_id': 'tg563',
#   'cf_id': 65,
#   'name': 'Trinh Gregoire',
#   'email': 'tgregoire@live.com'},
#  {'backer_id': 'kc571',
#   'cf_id': 968,
#   'name': 'Karin Celano',
#   'email': 'kcelano@yandex.com'},
#  {'backer_id': 'sd121',
#   'cf_id': 1114,
#   'name': 'Sofia Decker',
#   'email': 'sdecker@yahoo.com'},
#  {'backer_id': 'sk744',
#   'cf_id': 65,
#   'name': 'Sherise Keller',
#   'email': 'skeller@outlook.com'},
#  {'backer_id': 'km642',
#   'cf_id': 65,
#   'name': 'Kirby Michel',
#   'email': 'kmichel@gmail.com'},
#  {'backer_id': 'fu320',
#   'cf_id': 65,
#   'name': 'Florentine Ungaro',
#   'email': 'fungaro@yandex.com'},
#  {'backer_id': 'ld180',
#   'cf_id': 1911,
#   'name': 'Louise Dejesus',
#   'email': 'ldejesus@yandex.com'},
#  {'backer_id': 'ds377',
#   'cf_id': 65,
#   'name': 'Daniele Suarez',
#   'email': 'dsuarez@yahoo.com'},
#  {'backer_id': 'bb692',
#   'cf_id': 65,
#   'name': 'Beckie Buchholz',
#   'email': 'bbuchholz@live.com'},
#  {'backer_id': 'wd557',
#   'cf_id': 563,
#   'name': 'William Dickson',
#   'email': 'wdickson@yandex.com'},
#  {'backer_id': 'jd905',
#   'cf_id': 65,
#   'name': 'Jolie Daugherty',
#   'email': 'jdaugherty@gmail.com'},
#  {'backer_id': 'dd770',
#   'cf_id': 65,
#   'name': 'Detta Dressler',
#   'email': 'ddressler@yahoo.com'},
#  {'backer_id': 'cv698',
#   'cf_id': 238,
#   'name': 'Clifton Villette',
#   'email': 'cvillette@outlook.com'},
#  {'backer_id': 'cn307',
#   'cf_id': 968,
#   'name': 'Cythia Netti',
#   'email': 'cnetti@outlook.com'},
#  {'backer_id': 'eb198',
#   'cf_id': 1572,
#   'name': 'Elsbeth Butler',
#   'email': 'ebutler@yahoo.com'},
#  {'backer_id': 'am869',
#   'cf_id': 65,
#   'name': 'Ambrine Mann',
#   'email': 'amann@yahoo.com'},
#  {'backer_id': 'gr400',
#   'cf_id': 1911,
#   'name': 'Gerald Robert',
#   'email': 'grobert@protonmail.com'},
#  {'backer_id': 'az657',
#   'cf_id': 563,
#   'name': 'Assunta Zezza',
#   'email': 'azezza@live.com'},
#  {'backer_id': 'kc598',
#   'cf_id': 1572,
#   'name': 'Kerstin Campbell',
#   'email': 'kcampbell@protonmail.com'},
#  {'backer_id': 'lb588',
#   'cf_id': 65,
#   'name': 'Lino Brock',
#   'email': 'lbrock@outlook.com'},
#  {'backer_id': 'rl866',
#   'cf_id': 65,
#   'name': 'Rubie Levasseur',
#   'email': 'rlevasseur@gmail.com'},
#  {'backer_id': 'jf340',
#   'cf_id': 65,
#   'name': 'Johann Flowers',
#   'email': 'jflowers@live.com'},
#  {'backer_id': 'tb384',
#   'cf_id': 1572,
#   'name': 'Thibaud Bullock',
#   'email': 'tbullock@yahoo.com'},
#  {'backer_id': 'dg290',
#   'cf_id': 65,
#   'name': 'Dan Gallois',
#   'email': 'dgallois@outlook.com'},
#  {'backer_id': 'rr518',
#   'cf_id': 65,
#   'name': 'Rolf Richards',
#   'email': 'rrichards@live.com'},
#  {'backer_id': 'sh779',
#   'cf_id': 968,
#   'name': 'Selyan Hoffman',
#   'email': 'shoffman@outlook.com'},
#  {'backer_id': 'lw525',
#   'cf_id': 65,
#   'name': 'Lucca Weber',
#   'email': 'lweber@live.com'},
#  {'backer_id': 'sl474',
#   'cf_id': 563,
#   'name': 'Sydney Louvet',
#   'email': 'slouvet@gmail.com'},
#  {'backer_id': 'dp154',
#   'cf_id': 65,
#   'name': 'Dusty Paola',
#   'email': 'dpaola@outlook.com'},
#  {'backer_id': 'id770',
#   'cf_id': 238,
#   'name': 'Ilario Dressler',
#   'email': 'idressler@protonmail.com'},
#  {'backer_id': 'ek669',
#   'cf_id': 65,
#   'name': 'Emile Khan',
#   'email': 'ekhan@outlook.com'},
#  {'backer_id': 'eb945',
#   'cf_id': 65,
#   'name': 'Elliot Bonomo',
#   'email': 'ebonomo@yandex.com'},
#  {'backer_id': 'ag917',
#   'cf_id': 1114,
#   'name': 'Arvin Golden',
#   'email': 'agolden@yandex.com'},
#  {'backer_id': 'ac437',
#   'cf_id': 563,
#   'name': 'Ampelio Cabrera',
#   'email': 'acabrera@live.com'},
#  {'backer_id': 'sf583',
#   'cf_id': 1572,
#   'name': 'Somer Fuhrmann',
#   'email': 'sfuhrmann@yahoo.com'},
#  {'backer_id': 'sa973',
#   'cf_id': 65,
#   'name': 'Shanti Allard',
#   'email': 'sallard@yandex.com'},
#  {'backer_id': 'kc836',
#   'cf_id': 65,
#   'name': 'Konstanze Caroselli',
#   'email': 'kcaroselli@yandex.com'},
#  {'backer_id': 'bt844',
#   'cf_id': 65,
#   'name': 'Bellarmine Taylor',
#   'email': 'btaylor@outlook.com'},
#  {'backer_id': 'mf392',
#   'cf_id': 65,
#   'name': 'Matthew Fischer',
#   'email': 'mfischer@live.com'},
#  {'backer_id': 'dh568',
#   'cf_id': 65,
#   'name': 'Dan Hoffmann',
#   'email': 'dhoffmann@yandex.com'},
#  {'backer_id': 'iv880',
#   'cf_id': 968,
#   'name': 'Imelda Vallee',
#   'email': 'ivallee@gmail.com'},
#  {'backer_id': 'gl219',
#   'cf_id': 1572,
#   'name': 'Giancarlo Lindsey',
#   'email': 'glindsey@protonmail.com'},
#  {'backer_id': 'kb890',
#   'cf_id': 1572,
#   'name': 'Kris Brennan',
#   'email': 'kbrennan@protonmail.com'},
#  {'backer_id': 'jf901',
#   'cf_id': 65,
#   'name': 'Johnnie Fux',
#   'email': 'jfux@gmail.com'},
#  {'backer_id': 'ja340',
#   'cf_id': 1114,
#   'name': 'Janeth Adam',
#   'email': 'jadam@protonmail.com'},
#  {'backer_id': 'ar906',
#   'cf_id': 65,
#   'name': 'Agata Rosa',
#   'email': 'arosa@yahoo.com'},
#  {'backer_id': 'dc579',
#   'cf_id': 65,
#   'name': 'Dennise Cabrera',
#   'email': 'dcabrera@live.com'},
#  {'backer_id': 'gg660',
#   'cf_id': 65,
#   'name': 'Garret Geier',
#   'email': 'ggeier@yahoo.com'},
#  {'backer_id': 'db112',
#   'cf_id': 65,
#   'name': 'Delia Beguin',
#   'email': 'dbeguin@yandex.com'},
#  {'backer_id': 'ld487',
#   'cf_id': 65,
#   'name': 'Louanne Damiani',
#   'email': 'ldamiani@outlook.com'},
#  {'backer_id': 'bj475',
#   'cf_id': 1572,
#   'name': 'Bronze Jenkins',
#   'email': 'bjenkins@protonmail.com'},
#  {'backer_id': 'mc838',
#   'cf_id': 65,
#   'name': 'Mila Coffey',
#   'email': 'mcoffey@protonmail.com'},
#  {'backer_id': 'he768',
#   'cf_id': 65,
#   'name': 'Hank Essert',
#   'email': 'hessert@gmail.com'},
#  {'backer_id': 'pm973',
#   'cf_id': 65,
#   'name': 'Paulina Marais',
#   'email': 'pmarais@protonmail.com'},
#  {'backer_id': 'bf986',
#   'cf_id': 65,
#   'name': 'Beatrice Fulco',
#   'email': 'bfulco@gmail.com'},
#  {'backer_id': 'sb322',
#   'cf_id': 65,
#   'name': 'Sudie Burgess',
#   'email': 'sburgess@yandex.com'},
#  {'backer_id': 'ps571',
#   'cf_id': 563,
#   'name': 'Prince Suarez',
#   'email': 'psuarez@yahoo.com'},
#  {'backer_id': 'mb333',
#   'cf_id': 1572,
#   'name': 'Mitzi Biermann',
#   'email': 'mbiermann@gmail.com'},
#  {'backer_id': 'ab290',
#   'cf_id': 1572,
#   'name': 'Aminata Bru',
#   'email': 'abru@yahoo.com'},
#  {'backer_id': 'jm190',
#   'cf_id': 968,
#   'name': 'Jina Magrino',
#   'email': 'jmagrino@live.com'},
#  {'backer_id': 'rg933',
#   'cf_id': 65,
#   'name': 'Rosena Gould',
#   'email': 'rgould@gmail.com'},
#  {'backer_id': 'ik787',
#   'cf_id': 1572,
#   'name': 'Issac Kline',
#   'email': 'ikline@live.com'},
#  {'backer_id': 'rl982',
#   'cf_id': 65,
#   'name': 'Roderica Lehmann',
#   'email': 'rlehmann@gmail.com'},
#  {'backer_id': 'ac179',
#   'cf_id': 65,
#   'name': 'Ariah Comte',
#   'email': 'acomte@yandex.com'},
#  {'backer_id': 'eg193',
#   'cf_id': 238,
#   'name': 'Ellis Gamble',
#   'email': 'egamble@yahoo.com'},
#  {'backer_id': 'fl258',
#   'cf_id': 65,
#   'name': 'Friedrich Lott',
#   'email': 'flott@yandex.com'},
#  {'backer_id': 'mb203',
#   'cf_id': 1114,
#   'name': 'Marilou Beutel',
#   'email': 'mbeutel@gmail.com'},
#  {'backer_id': 'en399',
#   'cf_id': 65,
#   'name': 'Elene Navarro',
#   'email': 'enavarro@yahoo.com'},
#  {'backer_id': 'mr756',
#   'cf_id': 968,
#   'name': 'Mac Raffin',
#   'email': 'mraffin@yahoo.com'},
#  {'backer_id': 'sc271',
#   'cf_id': 563,
#   'name': 'Shona Carr',
#   'email': 'scarr@outlook.com'},
#  {'backer_id': 'xg684',
#   'cf_id': 1572,
#   'name': 'Ximena Guy',
#   'email': 'xguy@protonmail.com'},
#  {'backer_id': 'ab829',
#   'cf_id': 563,
#   'name': 'Arnaud Becker',
#   'email': 'abecker@live.com'},
#  {'backer_id': 'fd404',
#   'cf_id': 65,
#   'name': 'Fiore Desautels',
#   'email': 'fdesautels@live.com'},
#  {'backer_id': 'rm849',
#   'cf_id': 563,
#   'name': 'Robby Mccray',
#   'email': 'rmccray@gmail.com'},
#  {'backer_id': 'lr658',
#   'cf_id': 65,
#   'name': 'Louis Rush',
#   'email': 'lrush@protonmail.com'},
#  {'backer_id': 'sh994',
#   'cf_id': 65,
#   'name': 'Serena Holzknecht',
#   'email': 'sholzknecht@protonmail.com'},
#  {'backer_id': 'zv654',
#   'cf_id': 65,
#   'name': 'Zan Verdier',
#   'email': 'zverdier@yahoo.com'},
#  {'backer_id': 'hb861',
#   'cf_id': 1572,
#   'name': 'Hipolito Baldocchi',
#   'email': 'hbaldocchi@gmail.com'},
#  {'backer_id': 'hb280',
#   'cf_id': 65,
#   'name': 'Hollis Barnett',
#   'email': 'hbarnett@live.com'},
#  {'backer_id': 'be560',
#   'cf_id': 65,
#   'name': 'Barend Edwards',
#   'email': 'bedwards@yandex.com'},
#  {'backer_id': 'lh820',
#   'cf_id': 563,
#   'name': 'Loane Holst',
#   'email': 'lholst@live.com'},
#  {'backer_id': 'zp659',
#   'cf_id': 1572,
#   'name': 'Zeno Pruneau',
#   'email': 'zpruneau@gmail.com'},
#  {'backer_id': 'de758',
#   'cf_id': 1114,
#   'name': 'Devon Epifano',
#   'email': 'depifano@protonmail.com'},
#  {'backer_id': 'jb896',
#   'cf_id': 65,
#   'name': 'Jarrett Barrera',
#   'email': 'jbarrera@gmail.com'},
#  {'backer_id': 'wb355',
#   'cf_id': 238,
#   'name': 'Walburg Burris',
#   'email': 'wburris@outlook.com'},
#  {'backer_id': 'rd560',
#   'cf_id': 65,
#   'name': 'Raffaela Darras',
#   'email': 'rdarras@gmail.com'},
#  {'backer_id': 'er574',
#   'cf_id': 1572,
#   'name': 'Eli Resta',
#   'email': 'eresta@outlook.com'},
#  {'backer_id': 'jc163',
#   'cf_id': 65,
#   'name': 'Jin Chen',
#   'email': 'jchen@outlook.com'},
#  {'backer_id': 'kb942',
#   'cf_id': 1114,
#   'name': 'Katja Butler',
#   'email': 'kbutler@protonmail.com'},
#  {'backer_id': 'af969',
#   'cf_id': 563,
#   'name': 'Allegra Fiedler',
#   'email': 'afiedler@yandex.com'},
#  {'backer_id': 'bp212',
#   'cf_id': 1572,
#   'name': 'Benton Pereira',
#   'email': 'bpereira@live.com'},
#  {'backer_id': 'tc947',
#   'cf_id': 65,
#   'name': 'Tesha Carpinello',
#   'email': 'tcarpinello@outlook.com'},
#  {'backer_id': 'ak106',
#   'cf_id': 1572,
#   'name': 'Anneli Kaufman',
#   'email': 'akaufman@outlook.com'},
#  {'backer_id': 'mr294',
#   'cf_id': 1572,
#   'name': 'Merle Rowe',
#   'email': 'mrowe@yahoo.com'},
#  {'backer_id': 'bb365',
#   'cf_id': 65,
#   'name': 'Bev Bellotti',
#   'email': 'bbellotti@yandex.com'},
#  {'backer_id': 'bj274',
#   'cf_id': 65,
#   'name': 'Blake Jenkins',
#   'email': 'bjenkins@outlook.com'},
#  {'backer_id': 'qw345',
#   'cf_id': 1572,
#   'name': 'Qiana Washington',
#   'email': 'qwashington@gmail.com'},
#  {'backer_id': 'ra925',
#   'cf_id': 65,
#   'name': 'Rayane Adam',
#   'email': 'radam@live.com'},
#  {'backer_id': 'pg824',
#   'cf_id': 968,
#   'name': 'Petronella Guilbaud',
#   'email': 'pguilbaud@outlook.com'},
#  {'backer_id': 'ef414',
#   'cf_id': 65,
#   'name': 'Elodia Forgione',
#   'email': 'eforgione@gmail.com'},
#  {'backer_id': 'rp650',
#   'cf_id': 238,
#   'name': 'Ryan Potts',
#   'email': 'rpotts@protonmail.com'},
#  {'backer_id': 'se972',
#   'cf_id': 1114,
#   'name': 'Sigmund Everett',
#   'email': 'severett@yahoo.com'},
#  {'backer_id': 'sd958',
#   'cf_id': 65,
#   'name': 'Serafina Desroches',
#   'email': 'sdesroches@yahoo.com'},
#  {'backer_id': 'mb304',
#   'cf_id': 65,
#   'name': 'Murray Barrese',
#   'email': 'mbarrese@yandex.com'},
#  {'backer_id': 'lr409',
#   'cf_id': 563,
#   'name': 'Luis Roberts',
#   'email': 'lroberts@protonmail.com'},
#  {'backer_id': 'fm559',
#   'cf_id': 65,
#   'name': 'Felicia Mcneil',
#   'email': 'fmcneil@outlook.com'},
#  {'backer_id': 'wd714',
#   'cf_id': 65,
#   'name': 'Willette Dattoli',
#   'email': 'wdattoli@outlook.com'},
#  {'backer_id': 'ls638',
#   'cf_id': 1572,
#   'name': 'Lucas Stephens',
#   'email': 'lstephens@protonmail.com'},
#  {'backer_id': 'am362',
#   'cf_id': 65,
#   'name': 'Amo Moses',
#   'email': 'amoses@outlook.com'},
#  {'backer_id': 'ta190',
#   'cf_id': 563,
#   'name': 'Tandy Acker',
#   'email': 'tacker@outlook.com'},
#  {'backer_id': 'rb753',
#   'cf_id': 65,
#   'name': 'Rolf Biron',
#   'email': 'rbiron@outlook.com'},
#  {'backer_id': 'cc594',
#   'cf_id': 65,
#   'name': 'Catharina Cappella',
#   'email': 'ccappella@gmail.com'},
#  {'backer_id': 'vh915',
#   'cf_id': 65,
#   'name': 'Virgilio Hyde',
#   'email': 'vhyde@live.com'},
#  {'backer_id': 'og539',
#   'cf_id': 65,
#   'name': 'Ollie Gwerder',
#   'email': 'ogwerder@yandex.com'},
#  {'backer_id': 'dd470',
#   'cf_id': 1911,
#   'name': 'Daniela Demers',
#   'email': 'ddemers@yahoo.com'},
#  {'backer_id': 'ap718',
#   'cf_id': 238,
#   'name': 'Angel Peragine',
#   'email': 'aperagine@live.com'},
#  {'backer_id': 'vw158',
#   'cf_id': 1572,
#   'name': 'Vicenzo Wells',
#   'email': 'vwells@yandex.com'},
#  {'backer_id': 'fh696',
#   'cf_id': 2284,
#   'name': 'Fernanda Hodges',
#   'email': 'fhodges@yandex.com'},
#  {'backer_id': 'df617',
#   'cf_id': 968,
#   'name': 'Darrin Fiedler',
#   'email': 'dfiedler@yahoo.com'},
#  {'backer_id': 'jv716',
#   'cf_id': 65,
#   'name': 'Janine Veronesi',
#   'email': 'jveronesi@gmail.com'},
#  {'backer_id': 'tc807',
#   'cf_id': 65,
#   'name': 'Terenzio Carver',
#   'email': 'tcarver@gmail.com'},
#  {'backer_id': 'me460',
#   'cf_id': 563,
#   'name': 'Magali Eilerts',
#   'email': 'meilerts@gmail.com'},
#  {'backer_id': 'kp942',
#   'cf_id': 1572,
#   'name': 'Kimber Puech',
#   'email': 'kpuech@protonmail.com'},
#  {'backer_id': 'xp438',
#   'cf_id': 563,
#   'name': 'Xenia Pergola',
#   'email': 'xpergola@yandex.com'},
#  {'backer_id': 'af564',
#   'cf_id': 1572,
#   'name': 'Arlena Fox',
#   'email': 'afox@protonmail.com'},
#  {'backer_id': 'wn746',
#   'cf_id': 1114,
#   'name': 'Wilfred Nazzaro',
#   'email': 'wnazzaro@yahoo.com'},
#  {'backer_id': 'ad641',
#   'cf_id': 1572,
#   'name': 'Angelina Decker',
#   'email': 'adecker@yahoo.com'},
#  {'backer_id': 'rs660',
#   'cf_id': 65,
#   'name': 'Ressie Schneider',
#   'email': 'rschneider@live.com'},
#  {'backer_id': 'dp520',
#   'cf_id': 65,
#   'name': 'Daine Pruneau',
#   'email': 'dpruneau@outlook.com'},
#  {'backer_id': 'me520',
#   'cf_id': 65,
#   'name': 'Marius Emilio',
#   'email': 'memilio@gmail.com'},
#  {'backer_id': 'es977',
#   'cf_id': 1572,
#   'name': 'Emily Stout',
#   'email': 'estout@gmail.com'},
#  {'backer_id': 'sd883',
#   'cf_id': 3138,
#   'name': 'Shaunna Dreher',
#   'email': 'sdreher@yahoo.com'},
#  {'backer_id': 'tb283',
#   'cf_id': 65,
#   'name': 'Toi Briere',
#   'email': 'tbriere@outlook.com'},
#  {'backer_id': 'eb415',
#   'cf_id': 65,
#   'name': 'Eliodoro Black',
#   'email': 'eblack@yahoo.com'},
#  {'backer_id': 'fb116',
#   'cf_id': 1572,
#   'name': 'Faustino Burgstaller',
#   'email': 'fburgstaller@outlook.com'},
#  {'backer_id': 'jb391',
#   'cf_id': 1572,
#   'name': 'Jeramy Benard',
#   'email': 'jbenard@yandex.com'},
#  {'backer_id': 'ac624',
#   'cf_id': 563,
#   'name': 'Annika Curtis',
#   'email': 'acurtis@live.com'},
#  {'backer_id': 'kc104',
#   'cf_id': 65,
#   'name': 'Kelia Campbell',
#   'email': 'kcampbell@protonmail.com'},
#  {'backer_id': 'dg582',
#   'cf_id': 65,
#   'name': 'Dario Gerst',
#   'email': 'dgerst@protonmail.com'},
#  {'backer_id': 'mb933',
#   'cf_id': 1572,
#   'name': 'Maryetta Bussa',
#   'email': 'mbussa@yahoo.com'},
#  {'backer_id': 'em898',
#   'cf_id': 65,
#   'name': 'Emerich Mccoy',
#   'email': 'emccoy@live.com'},
#  {'backer_id': 'tw982',
#   'cf_id': 968,
#   'name': 'Timothe Wilder',
#   'email': 'twilder@yandex.com'},
#  {'backer_id': 'ab575',
#   'cf_id': 65,
#   'name': 'Amadore Breitbarth',
#   'email': 'abreitbarth@protonmail.com'},
#  {'backer_id': 'dg744',
#   'cf_id': 1572,
#   'name': 'Dave Gaillard',
#   'email': 'dgaillard@live.com'},
#  {'backer_id': 'cj442',
#   'cf_id': 1572,
#   'name': 'Catrin Joseph',
#   'email': 'cjoseph@live.com'},
#  {'backer_id': 'lo117',
#   'cf_id': 65,
#   'name': 'Laverne Ortega',
#   'email': 'lortega@yandex.com'},
#  {'backer_id': 'bg270',
#   'cf_id': 65,
#   'name': 'Bulah Guay',
#   'email': 'bguay@yandex.com'},
#  {'backer_id': 'jc692',
#   'cf_id': 65,
#   'name': 'Jae Castellucci',
#   'email': 'jcastellucci@yahoo.com'},
#  {'backer_id': 'jf750',
#   'cf_id': 1572,
#   'name': 'Joseph Freeman',
#   'email': 'jfreeman@live.com'},
#  {'backer_id': 'lr317',
#   'cf_id': 968,
#   'name': 'Lena Robbins',
#   'email': 'lrobbins@live.com'},
#  {'backer_id': 'cp253',
#   'cf_id': 65,
#   'name': 'Charley Petitjean',
#   'email': 'cpetitjean@yandex.com'},
#  {'backer_id': 'vv330',
#   'cf_id': 65,
#   'name': 'Veronika Vesco',
#   'email': 'vvesco@live.com'},
#  {'backer_id': 'ch724',
#   'cf_id': 1572,
#   'name': 'Calandra Hofmeister',
#   'email': 'chofmeister@protonmail.com'},
#  {'backer_id': 'dm121',
#   'cf_id': 65,
#   'name': 'Devon Marques',
#   'email': 'dmarques@yandex.com'},
#  {'backer_id': 'lc141',
#   'cf_id': 65,
#   'name': 'Leon Carson',
#   'email': 'lcarson@gmail.com'},
#  {'backer_id': 'am966',
#   'cf_id': 65,
#   'name': 'Adelrico Meadows',
#   'email': 'ameadows@gmail.com'},
#  {'backer_id': 'ab249',
#   'cf_id': 65,
#   'name': 'Adel Becke',
#   'email': 'abecke@yahoo.com'},
#  {'backer_id': 'mb828',
#   'cf_id': 65,
#   'name': 'Mariya Babin',
#   'email': 'mbabin@outlook.com'},
#  {'backer_id': 'pu317',
#   'cf_id': 65,
#   'name': 'Peg Urciuoli',
#   'email': 'purciuoli@yandex.com'},
#  {'backer_id': 'cb515',
#   'cf_id': 1572,
#   'name': 'Clarita Barron',
#   'email': 'cbarron@protonmail.com'},
#  {'backer_id': 'so203',
#   'cf_id': 563,
#   'name': 'Silvia Olson',
#   'email': 'solson@gmail.com'},
#  {'backer_id': 'aa284',
#   'cf_id': 65,
#   'name': 'Armand Arnold',
#   'email': 'aarnold@live.com'},
#  {'backer_id': 'sc143',
#   'cf_id': 65,
#   'name': 'Sueann Casciani',
#   'email': 'scasciani@outlook.com'},
#  {'backer_id': 'je217',
#   'cf_id': 65,
#   'name': 'Jc Elliott',
#   'email': 'jelliott@yandex.com'},
#  {'backer_id': 'ke511',
#   'cf_id': 1114,
#   'name': 'Kalet Eaton',
#   'email': 'keaton@outlook.com'},
#  {'backer_id': 'oa673',
#   'cf_id': 563,
#   'name': 'Ottavia Abraham',
#   'email': 'oabraham@yandex.com'},
#  {'backer_id': 'sc432',
#   'cf_id': 968,
#   'name': 'Swanhild Cameron',
#   'email': 'scameron@yandex.com'},
#  {'backer_id': 'aj655',
#   'cf_id': 65,
#   'name': 'Alessandrina Jollenbeck',
#   'email': 'ajollenbeck@outlook.com'},
#  {'backer_id': 'jp351',
#   'cf_id': 968,
#   'name': 'Jamison Perona',
#   'email': 'jperona@live.com'},
#  {'backer_id': 'lj758',
#   'cf_id': 968,
#   'name': 'Louis Justice',
#   'email': 'ljustice@yahoo.com'},
#  {'backer_id': 'ps794',
#   'cf_id': 1572,
#   'name': 'Pablo Sykes',
#   'email': 'psykes@yandex.com'},
#  {'backer_id': 'nb202',
#   'cf_id': 1572,
#   'name': 'Nek Blecher',
#   'email': 'nblecher@yahoo.com'},
#  {'backer_id': 'gp356',
#   'cf_id': 968,
#   'name': 'Guadalupe Pannone',
#   'email': 'gpannone@outlook.com'},
#  {'backer_id': 'rb945',
#   'cf_id': 1572,
#   'name': 'Ramona Berg',
#   'email': 'rberg@yandex.com'},
#  {'backer_id': 'gw991',
#   'cf_id': 65,
#   'name': 'Gioconda Webster',
#   'email': 'gwebster@live.com'},
#  {'backer_id': 'gb896',
#   'cf_id': 910,
#   'name': 'George Bauers',
#   'email': 'gbauers@yahoo.com'},
#  {'backer_id': 'jm345',
#   'cf_id': 563,
#   'name': 'Julian Maillot',
#   'email': 'jmaillot@yandex.com'},
#  {'backer_id': 'ma565',
#   'cf_id': 1911,
#   'name': 'Melusina Asti',
#   'email': 'masti@yandex.com'},
#  {'backer_id': 'oh728',
#   'cf_id': 65,
#   'name': 'Ornella Hester',
#   'email': 'ohester@live.com'},
#  {'backer_id': 'dg119',
#   'cf_id': 1572,
#   'name': 'Dione Gass',
#   'email': 'dgass@yandex.com'},
#  {'backer_id': 'kd744',
#   'cf_id': 968,
#   'name': 'Konrad Damone',
#   'email': 'kdamone@yandex.com'},
#  {'backer_id': 'ww138',
#   'cf_id': 65,
#   'name': 'Walid Woods',
#   'email': 'wwoods@protonmail.com'},
#  {'backer_id': 'gb135',
#   'cf_id': 1572,
#   'name': 'Giana Blevins',
#   'email': 'gblevins@protonmail.com'},
#  {'backer_id': 'lp541',
#   'cf_id': 563,
#   'name': 'Lino Pires',
#   'email': 'lpires@yandex.com'},
#  {'backer_id': 'hm752',
#   'cf_id': 65,
#   'name': 'Helmina Mosco',
#   'email': 'hmosco@outlook.com'},
#  {'backer_id': 'ib452',
#   'cf_id': 1911,
#   'name': 'Inaya Barton',
#   'email': 'ibarton@yandex.com'},
#  {'backer_id': 'fc303',
#   'cf_id': 65,
#   'name': 'Francesca Chambers',
#   'email': 'fchambers@protonmail.com'},
#  {'backer_id': 'kb141',
#   'cf_id': 1114,
#   'name': 'Kenisha Bergfalk',
#   'email': 'kbergfalk@outlook.com'},
#  {'backer_id': 'is909',
#   'cf_id': 65,
#   'name': 'Ismael Sarrazin',
#   'email': 'isarrazin@live.com'},
#  {'backer_id': 'hv133',
#   'cf_id': 968,
#   'name': 'Holger Vitiello',
#   'email': 'hvitiello@protonmail.com'},
#  {'backer_id': 'nm163',
#   'cf_id': 65,
#   'name': 'Nayla Melendez',
#   'email': 'nmelendez@yahoo.com'},
#  {'backer_id': 'cs899',
#   'cf_id': 65,
#   'name': 'Camila Sciarretta',
#   'email': 'csciarretta@yandex.com'},
#  {'backer_id': 'lh190',
#   'cf_id': 65,
#   'name': 'Lucia Hatfield',
#   'email': 'lhatfield@gmail.com'},
#  {'backer_id': 'as260',
#   'cf_id': 65,
#   'name': 'Annetta Scholz',
#   'email': 'ascholz@live.com'},
#  {'backer_id': 'db149',
#   'cf_id': 65,
#   'name': 'Demarcus Barthelemy',
#   'email': 'dbarthelemy@gmail.com'},
#  {'backer_id': 'cg952',
#   'cf_id': 563,
#   'name': 'Clifton Garibaldi',
#   'email': 'cgaribaldi@live.com'},
#  {'backer_id': 'tm490',
#   'cf_id': 65,
#   'name': 'Tobias Mcintyre',
#   'email': 'tmcintyre@gmail.com'},
#  {'backer_id': 'lt569',
#   'cf_id': 65,
#   'name': 'Lalie Tyler',
#   'email': 'ltyler@outlook.com'},
#  {'backer_id': 'ce212',
#   'cf_id': 65,
#   'name': 'Cristiano Everhart',
#   'email': 'ceverhart@yandex.com'},
#  {'backer_id': 'sr285',
#   'cf_id': 2284,
#   'name': 'Shirl Rochon',
#   'email': 'srochon@live.com'},
#  {'backer_id': 'tc231',
#   'cf_id': 2882,
#   'name': 'Treena Ciampa',
#   'email': 'tciampa@yandex.com'},
#  {'backer_id': 'll471',
#   'cf_id': 968,
#   'name': 'Luther Leonard',
#   'email': 'lleonard@gmail.com'},
#  {'backer_id': 'aa130',
#   'cf_id': 65,
#   'name': 'Affonso Abraham',
#   'email': 'aabraham@outlook.com'},
#  {'backer_id': 'sb241',
#   'cf_id': 563,
#   'name': 'So Boilard',
#   'email': 'sboilard@yandex.com'},
#  {'backer_id': 'lb909',
#   'cf_id': 968,
#   'name': 'Luther Barberi',
#   'email': 'lbarberi@yahoo.com'},
#  {'backer_id': 'lw976',
#   'cf_id': 910,
#   'name': 'Leuther Webb',
#   'email': 'lwebb@gmail.com'},
#  {'backer_id': 'ab143',
#   'cf_id': 1114,
#   'name': 'Abel Burke',
#   'email': 'aburke@outlook.com'},
#  {'backer_id': 'cg893',
#   'cf_id': 65,
#   'name': 'Calogero Geiger',
#   'email': 'cgeiger@outlook.com'},
#  {'backer_id': 'nl492',
#   'cf_id': 65,
#   'name': 'Nelson Lemire',
#   'email': 'nlemire@yahoo.com'},
#  {'backer_id': 'nc285',
#   'cf_id': 1572,
#   'name': 'Nadene Cartelli',
#   'email': 'ncartelli@live.com'},
#  {'backer_id': 'ct703',
#   'cf_id': 65,
#   'name': 'Calvin Tate',
#   'email': 'ctate@yandex.com'},
#  {'backer_id': 'aw876',
#   'cf_id': 1572,
#   'name': 'Axel Watts',
#   'email': 'awatts@protonmail.com'},
#  {'backer_id': 'af506',
#   'cf_id': 563,
#   'name': 'Alda Feigenbaum',
#   'email': 'afeigenbaum@live.com'},
#  {'backer_id': 'es282',
#   'cf_id': 65,
#   'name': 'Elena Shields',
#   'email': 'eshields@outlook.com'},
#  {'backer_id': 'co633',
#   'cf_id': 65,
#   'name': 'Circinus Odom',
#   'email': 'codom@yahoo.com'},
#  {'backer_id': 'mh163',
#   'cf_id': 65,
#   'name': 'Marietta Holzmann',
#   'email': 'mholzmann@yandex.com'},
#  {'backer_id': 'pc978',
#   'cf_id': 65,
#   'name': 'Peg Corriveau',
#   'email': 'pcorriveau@protonmail.com'},
#  {'backer_id': 'gc386',
#   'cf_id': 2882,
#   'name': 'Gregory Cianciolo',
#   'email': 'gcianciolo@live.com'},
#  {'backer_id': 'nl252',
#   'cf_id': 1114,
#   'name': 'Nolhan Lindsey',
#   'email': 'nlindsey@live.com'},
#  {'backer_id': 'rb829',
#   'cf_id': 1572,
#   'name': 'Romero Blau',
#   'email': 'rblau@gmail.com'},
#  {'backer_id': 'gl884',
#   'cf_id': 65,
#   'name': 'Genaro Larose',
#   'email': 'glarose@yahoo.com'},
#  {'backer_id': 'og404',
#   'cf_id': 65,
#   'name': 'Oralee Garbarino',
#   'email': 'ogarbarino@live.com'},
#  {'backer_id': 'kr745',
#   'cf_id': 1911,
#   'name': 'Karsten Riggs',
#   'email': 'kriggs@live.com'},
#  {'backer_id': 'jc104',
#   'cf_id': 238,
#   'name': 'Joris Cline',
#   'email': 'jcline@yandex.com'},
#  {'backer_id': 'th958',
#   'cf_id': 968,
#   'name': 'Tasha Holzknecht',
#   'email': 'tholzknecht@live.com'},
#  {'backer_id': 'jb207',
#   'cf_id': 65,
#   'name': 'Jarrett Beaumont',
#   'email': 'jbeaumont@yandex.com'},
#  {'backer_id': 'lm386',
#   'cf_id': 65,
#   'name': 'Laverne Maddalone',
#   'email': 'lmaddalone@yahoo.com'},
#  {'backer_id': 'ic277',
#   'cf_id': 968,
#   'name': 'Imre Carlson',
#   'email': 'icarlson@live.com'},
#  {'backer_id': 'ab714',
#   'cf_id': 968,
#   'name': 'Angel Brennan',
#   'email': 'abrennan@live.com'},
#  {'backer_id': 'jm813',
#   'cf_id': 2488,
#   'name': 'Jinny Michaud',
#   'email': 'jmichaud@live.com'},
#  {'backer_id': 'ma226',
#   'cf_id': 238,
#   'name': 'Maryam Armellino',
#   'email': 'marmellino@outlook.com'},
#  {'backer_id': 'lm154',
#   'cf_id': 1114,
#   'name': 'Lyle Massey',
#   'email': 'lmassey@yandex.com'},
#  {'backer_id': 'pp209',
#   'cf_id': 65,
#   'name': 'Peppe Pohl',
#   'email': 'ppohl@gmail.com'},
#  {'backer_id': 'ss320',
#   'cf_id': 1114,
#   'name': 'Shakita Sabatier',
#   'email': 'ssabatier@gmail.com'},
#  {'backer_id': 'lb805',
#   'cf_id': 1572,
#   'name': 'Lynwood Bozza',
#   'email': 'lbozza@yahoo.com'},
#  {'backer_id': 'sf196',
#   'cf_id': 968,
#   'name': 'Siglinde Flores',
#   'email': 'sflores@live.com'},
#  {'backer_id': 'jc350',
#   'cf_id': 1572,
#   'name': 'Jaden Castro',
#   'email': 'jcastro@outlook.com'},
#  {'backer_id': 'bh958',
#   'cf_id': 1114,
#   'name': 'Bartolo Haupt',
#   'email': 'bhaupt@outlook.com'},
#  {'backer_id': 'vp800',
#   'cf_id': 65,
#   'name': 'Venetta Perugini',
#   'email': 'vperugini@gmail.com'},
#  {'backer_id': 'ec148',
#   'cf_id': 1572,
#   'name': 'Ellsworth Clements',
#   'email': 'eclements@yahoo.com'},
#  {'backer_id': 'ha431',
#   'cf_id': 65,
#   'name': 'Harbin Alston',
#   'email': 'halston@outlook.com'},
#  {'backer_id': 'sw972',
#   'cf_id': 65,
#   'name': 'Syrine Walter',
#   'email': 'swalter@yahoo.com'},
#  {'backer_id': 'sb891',
#   'cf_id': 1572,
#   'name': 'Sansone Bisaillon',
#   'email': 'sbisaillon@protonmail.com'},
#  {'backer_id': 'sf735',
#   'cf_id': 1114,
#   'name': 'Shantay Fiori',
#   'email': 'sfiori@protonmail.com'},
#  {'backer_id': 'mp538',
#   'cf_id': 563,
#   'name': 'Mary Prince',
#   'email': 'mprince@protonmail.com'},
#  {'backer_id': 'cf904',
#   'cf_id': 1572,
#   'name': 'Catrin Ferguson',
#   'email': 'cferguson@gmail.com'},
#  {'backer_id': 'gs818',
#   'cf_id': 1572,
#   'name': 'Gianpiero Samson',
#   'email': 'gsamson@yandex.com'},
#  {'backer_id': 'ra782',
#   'cf_id': 1572,
#   'name': 'Robert Altieri',
#   'email': 'raltieri@protonmail.com'},
#  {'backer_id': 'yc752',
#   'cf_id': 1911,
#   'name': 'Yvone Capodanno',
#   'email': 'ycapodanno@live.com'},
#  {'backer_id': 'le377',
#   'cf_id': 563,
#   'name': 'Lucetta Eichel',
#   'email': 'leichel@protonmail.com'},
#  {'backer_id': 'ja139',
#   'cf_id': 968,
#   'name': 'Jalisa Anastasi',
#   'email': 'janastasi@yandex.com'},
#  {'backer_id': 'jf881',
#   'cf_id': 65,
#   'name': 'Jessi Farley',
#   'email': 'jfarley@yahoo.com'},
#  {'backer_id': 'am638',
#   'cf_id': 1114,
#   'name': 'Adolph Merrill',
#   'email': 'amerrill@gmail.com'},
#  {'backer_id': 'rh663',
#   'cf_id': 65,
#   'name': 'Riyad Holst',
#   'email': 'rholst@outlook.com'},
#  {'backer_id': 'dl438',
#   'cf_id': 238,
#   'name': 'Donatien Lefrancois',
#   'email': 'dlefrancois@yandex.com'},
#  {'backer_id': 'je184',
#   'cf_id': 1114,
#   'name': 'Jere Evans',
#   'email': 'jevans@outlook.com'},
#  {'backer_id': 'xg938',
#   'cf_id': 65,
#   'name': 'Xandi Glenn',
#   'email': 'xglenn@live.com'},
#  {'backer_id': 'mg208',
#   'cf_id': 563,
#   'name': 'Marianne Geiger',
#   'email': 'mgeiger@outlook.com'},
#  {'backer_id': 'ag672',
#   'cf_id': 65,
#   'name': 'Alonzo Gautier',
#   'email': 'agautier@protonmail.com'},
#  {'backer_id': 'sc991',
#   'cf_id': 65,
#   'name': 'Santo Cornacchia',
#   'email': 'scornacchia@yahoo.com'},
#  {'backer_id': 'ar456',
#   'cf_id': 238,
#   'name': 'Aleida Robertson',
#   'email': 'arobertson@yahoo.com'},
#  {'backer_id': 'an122',
#   'cf_id': 65,
#   'name': 'Alexandra Nolan',
#   'email': 'anolan@yandex.com'},
#  {'backer_id': 'mh749',
#   'cf_id': 65,
#   'name': 'Marina Habich',
#   'email': 'mhabich@protonmail.com'},
#  {'backer_id': 'ac765',
#   'cf_id': 65,
#   'name': 'Agnella Cloutier',
#   'email': 'acloutier@yahoo.com'},
#  {'backer_id': 'ln560',
#   'cf_id': 563,
#   'name': 'Loralee Nerone',
#   'email': 'lnerone@live.com'},
#  {'backer_id': 'dm881',
#   'cf_id': 1114,
#   'name': 'Dot Moore',
#   'email': 'dmoore@protonmail.com'},
#  {'backer_id': 'wm699',
#   'cf_id': 65,
#   'name': 'Wolf Morin',
#   'email': 'wmorin@gmail.com'},
#  {'backer_id': 'ca628',
#   'cf_id': 1114,
#   'name': 'Ciel Augustin',
#   'email': 'caugustin@yandex.com'},
#  {'backer_id': 'ls538',
#   'cf_id': 1114,
#   'name': 'Leontina Saucier',
#   'email': 'lsaucier@live.com'},
#  {'backer_id': 'kr958',
#   'cf_id': 563,
#   'name': 'Kathern Rodriquez',
#   'email': 'krodriquez@live.com'},
#  {'backer_id': 'ad265',
#   'cf_id': 65,
#   'name': 'Alder Dressler',
#   'email': 'adressler@outlook.com'},
#  {'backer_id': 'am627',
#   'cf_id': 1572,
#   'name': 'Aroghetto Manza',
#   'email': 'amanza@yahoo.com'},
#  {'backer_id': 'rp666',
#   'cf_id': 1572,
#   'name': 'Roberto Perry',
#   'email': 'rperry@gmail.com'},
#  {'backer_id': 'rs221',
#   'cf_id': 65,
#   'name': 'Reena Shaw',
#   'email': 'rshaw@protonmail.com'},
#  {'backer_id': 'ma490',
#   'cf_id': 65,
#   'name': 'Melina Abeln',
#   'email': 'mabeln@yandex.com'},
#  {'backer_id': 'xd210',
#   'cf_id': 65,
#   'name': 'Xavier Delahaye',
#   'email': 'xdelahaye@yahoo.com'},
#  {'backer_id': 'mc413',
#   'cf_id': 563,
#   'name': 'Moses Cece',
#   'email': 'mcece@protonmail.com'},
#  {'backer_id': 'ss568',
#   'cf_id': 1572,
#   'name': 'Sheilah Shaw',
#   'email': 'sshaw@yandex.com'},
#  {'backer_id': 'dr174',
#   'cf_id': 563,
#   'name': 'Daniela Rhodes',
#   'email': 'drhodes@gmail.com'},
#  {'backer_id': 'vb927',
#   'cf_id': 563,
#   'name': 'Viviana Belhumeur',
#   'email': 'vbelhumeur@protonmail.com'},
#  {'backer_id': 'ms327',
#   'cf_id': 65,
#   'name': 'Mireille Stanley',
#   'email': 'mstanley@protonmail.com'},
#  {'backer_id': 'lf675',
#   'cf_id': 1911,
#   'name': 'Lynetta Frank',
#   'email': 'lfrank@live.com'},
#  {'backer_id': 'hb499',
#   'cf_id': 65,
#   'name': 'Hermann Buckholtz',
#   'email': 'hbuckholtz@gmail.com'},
#  {'backer_id': 'lb187',
#   'cf_id': 65,
#   'name': 'Leane Boulanger',
#   'email': 'lboulanger@outlook.com'},
#  {'backer_id': 'um200',
#   'cf_id': 65,
#   'name': 'Ugo Mammone',
#   'email': 'umammone@yahoo.com'},
#  {'backer_id': 'gh932',
#   'cf_id': 65,
#   'name': 'Gail Hewitt',
#   'email': 'ghewitt@outlook.com'},
#  {'backer_id': 'kl672',
#   'cf_id': 65,
#   'name': 'Kermit Lowery',
#   'email': 'klowery@gmail.com'},
#  {'backer_id': 'ab491',
#   'cf_id': 563,
#   'name': 'Alois Behrend',
#   'email': 'abehrend@live.com'},
#  {'backer_id': 'bb348',
#   'cf_id': 1572,
#   'name': 'Bonito Bon',
#   'email': 'bbon@live.com'},
#  {'backer_id': 'jv337',
#   'cf_id': 2882,
#   'name': 'Jacinda Verde',
#   'email': 'jverde@yahoo.com'},
#  {'backer_id': 'lh149',
#   'cf_id': 65,
#   'name': 'Lloyd Holden',
#   'email': 'lholden@outlook.com'},
#  {'backer_id': 'kw599',
#   'cf_id': 3138,
#   'name': 'Kurigunde Wolfe',
#   'email': 'kwolfe@protonmail.com'},
#  {'backer_id': 'mh683',
#   'cf_id': 65,
#   'name': 'Marvin Hummel',
#   'email': 'mhummel@yahoo.com'},
#  {'backer_id': 'bm342',
#   'cf_id': 65,
#   'name': 'Baiardo Maglione',
#   'email': 'bmaglione@gmail.com'},
#  {'backer_id': 'il539',
#   'cf_id': 1114,
#   'name': 'Isaias Lyons',
#   'email': 'ilyons@yahoo.com'},
#  {'backer_id': 'jl327',
#   'cf_id': 563,
#   'name': 'Johnnie Le',
#   'email': 'jle@protonmail.com'},
#  {'backer_id': 'wf249',
#   'cf_id': 65,
#   'name': 'Walker Friedrich',
#   'email': 'wfriedrich@live.com'},
#  {'backer_id': 'ba539',
#   'cf_id': 1572,
#   'name': 'Benedict Allen',
#   'email': 'ballen@protonmail.com'},
#  {'backer_id': 'sj553',
#   'cf_id': 563,
#   'name': 'Sung Jordan',
#   'email': 'sjordan@gmail.com'},
#  {'backer_id': 'gb371',
#   'cf_id': 563,
#   'name': 'Garfield Bonnard',
#   'email': 'gbonnard@yahoo.com'},
#  {'backer_id': 'hm715',
#   'cf_id': 1572,
#   'name': 'Hansel Mecca',
#   'email': 'hmecca@outlook.com'},
#  {'backer_id': 'ec905',
#   'cf_id': 1114,
#   'name': 'Emy Chapman',
#   'email': 'echapman@gmail.com'},
#  {'backer_id': 'lw634',
#   'cf_id': 65,
#   'name': 'Lucetta Wilcox',
#   'email': 'lwilcox@outlook.com'},
#  {'backer_id': 'dh507',
#   'cf_id': 65,
#   'name': 'Danial Hummel',
#   'email': 'dhummel@yahoo.com'},
#  {'backer_id': 'mr622',
#   'cf_id': 65,
#   'name': 'Marion Ribeiro',
#   'email': 'mribeiro@gmail.com'},
#  {'backer_id': 'gs461',
#   'cf_id': 1572,
#   'name': 'Gilbert Spaziani',
#   'email': 'gspaziani@gmail.com'},
#  {'backer_id': 'gb648',
#   'cf_id': 563,
#   'name': 'Genevra Bentley',
#   'email': 'gbentley@gmail.com'},
#  {'backer_id': 'eo125',
#   'cf_id': 563,
#   'name': 'Emilio Owen',
#   'email': 'eowen@yahoo.com'},
#  {'backer_id': 'rb185',
#   'cf_id': 1572,
#   'name': 'Reid Borchard',
#   'email': 'rborchard@gmail.com'},
#  {'backer_id': 'og865',
#   'cf_id': 563,
#   'name': 'Oscar Gallant',
#   'email': 'ogallant@live.com'},
#  {'backer_id': 'tr733',
#   'cf_id': 563,
#   'name': 'Titouan Reginato',
#   'email': 'treginato@live.com'},
#  {'backer_id': 'ac323',
#   'cf_id': 65,
#   'name': 'Aniella Coleman',
#   'email': 'acoleman@yandex.com'},
#  {'backer_id': 'lo326',
#   'cf_id': 1911,
#   'name': 'Laurena Ortiz',
#   'email': 'lortiz@live.com'},
#  {'backer_id': 'hc889',
#   'cf_id': 563,
#   'name': 'Helaine Carignan',
#   'email': 'hcarignan@live.com'},
#  {'backer_id': 'hv904',
#   'cf_id': 65,
#   'name': 'Harold Vinci',
#   'email': 'hvinci@yandex.com'},
#  {'backer_id': 'md370',
#   'cf_id': 1114,
#   'name': 'Monte Dillon',
#   'email': 'mdillon@yandex.com'},
#  {'backer_id': 'sb514',
#   'cf_id': 1572,
#   'name': 'Shondra Bach',
#   'email': 'sbach@protonmail.com'},
#  {'backer_id': 'sf324',
#   'cf_id': 1572,
#   'name': 'Saul Fayolle',
#   'email': 'sfayolle@yahoo.com'},
#  {'backer_id': 'eb537',
#   'cf_id': 968,
#   'name': 'Etienne Buonopane',
#   'email': 'ebuonopane@live.com'},
#  {'backer_id': 'bn189',
#   'cf_id': 65,
#   'name': 'Beatrix Noble',
#   'email': 'bnoble@protonmail.com'},
#  {'backer_id': 'sc931',
#   'cf_id': 1114,
#   'name': 'Seema Cherry',
#   'email': 'scherry@protonmail.com'},
#  {'backer_id': 'th234',
#   'cf_id': 65,
#   'name': 'Toby Haupt',
#   'email': 'thaupt@gmail.com'},
#  {'backer_id': 'lb460',
#   'cf_id': 1114,
#   'name': 'Lamar Berger',
#   'email': 'lberger@yahoo.com'},
#  {'backer_id': 'sp161',
#   'cf_id': 563,
#   'name': 'Suzanne Paniccia',
#   'email': 'spaniccia@gmail.com'},
#  {'backer_id': 'bm476',
#   'cf_id': 238,
#   'name': 'Bianka Massey',
#   'email': 'bmassey@yandex.com'},
#  {'backer_id': 'ta391',
#   'cf_id': 563,
#   'name': 'Tomika Andrews',
#   'email': 'tandrews@protonmail.com'},
#  {'backer_id': 'bm966',
#   'cf_id': 1572,
#   'name': 'Bertha Maurin',
#   'email': 'bmaurin@protonmail.com'},
#  {'backer_id': 'nm952',
#   'cf_id': 1911,
#   'name': 'Nyla Mcconnell',
#   'email': 'nmcconnell@outlook.com'},
#  {'backer_id': 'rg418',
#   'cf_id': 65,
#   'name': 'Ronny Gotti',
#   'email': 'rgotti@gmail.com'},
#  {'backer_id': 'rm381',
#   'cf_id': 65,
#   'name': 'Rollin Magne',
#   'email': 'rmagne@yahoo.com'},
#  {'backer_id': 'ab162',
#   'cf_id': 65,
#   'name': 'Anae Buzzeo',
#   'email': 'abuzzeo@protonmail.com'},
#  {'backer_id': 'gf246',
#   'cf_id': 1114,
#   'name': 'Giada Fisher',
#   'email': 'gfisher@protonmail.com'},
#  {'backer_id': 'ch750',
#   'cf_id': 1114,
#   'name': 'Cletus Hatfield',
#   'email': 'chatfield@yandex.com'},
#  {'backer_id': 'jg803',
#   'cf_id': 1114,
#   'name': 'Jeffrey Gerber',
#   'email': 'jgerber@yahoo.com'},
#  {'backer_id': 'pl955',
#   'cf_id': 563,
#   'name': 'Philomena Leduc',
#   'email': 'pleduc@yandex.com'},
#  {'backer_id': 'bc578',
#   'cf_id': 968,
#   'name': 'Bellissa Carpenter',
#   'email': 'bcarpenter@yahoo.com'},
#  {'backer_id': 'np469',
#   'cf_id': 65,
#   'name': 'Nadene Pittman',
#   'email': 'npittman@yahoo.com'},
#  {'backer_id': 'nj734',
#   'cf_id': 65,
#   'name': 'Nakita Jourdain',
#   'email': 'njourdain@live.com'},
#  {'backer_id': 'as672',
#   'cf_id': 1114,
#   'name': 'Alger Spatafore',
#   'email': 'aspatafore@yahoo.com'},
#  {'backer_id': 'lg912',
#   'cf_id': 65,
#   'name': 'Luna Gallegos',
#   'email': 'lgallegos@live.com'},
#  {'backer_id': 'rm719',
#   'cf_id': 1114,
#   'name': 'Rosanna Mcbride',
#   'email': 'rmcbride@yahoo.com'},
#  {'backer_id': 'kh931',
#   'cf_id': 1114,
#   'name': 'Kali Haber',
#   'email': 'khaber@outlook.com'},
#  {'backer_id': 'ml523',
#   'cf_id': 65,
#   'name': 'Medwin Lazzaro',
#   'email': 'mlazzaro@live.com'},
#  {'backer_id': 'df670',
#   'cf_id': 1114,
#   'name': 'Dany Floyd',
#   'email': 'dfloyd@gmail.com'},
#  {'backer_id': 'cs996',
#   'cf_id': 968,
#   'name': 'Cristiana Stafford',
#   'email': 'cstafford@yahoo.com'},
#  {'backer_id': 'wh607',
#   'cf_id': 238,
#   'name': 'Warner Hermann',
#   'email': 'whermann@protonmail.com'},
#  {'backer_id': 'jp523',
#   'cf_id': 65,
#   'name': 'Javier Pearson',
#   'email': 'jpearson@yahoo.com'},
#  {'backer_id': 'rw116',
#   'cf_id': 563,
#   'name': 'Romano Whitehead',
#   'email': 'rwhitehead@protonmail.com'},
#  {'backer_id': 'md744',
#   'cf_id': 65,
#   'name': 'Marquis Dietrich',
#   'email': 'mdietrich@protonmail.com'},
#  {'backer_id': 'df975',
#   'cf_id': 65,
#   'name': 'Donovan Filiatrault',
#   'email': 'dfiliatrault@yandex.com'},
#  {'backer_id': 'rl203',
#   'cf_id': 563,
#   'name': 'Robert Lopardo',
#   'email': 'rlopardo@live.com'},
#  {'backer_id': 'ab776',
#   'cf_id': 65,
#   'name': 'Anael Beck',
#   'email': 'abeck@live.com'},
#  {'backer_id': 'th710',
#   'cf_id': 1572,
#   'name': 'Teofila Horn',
#   'email': 'thorn@protonmail.com'},
#  {'backer_id': 'if257',
#   'cf_id': 1572,
#   'name': 'Ishild Fusillo',
#   'email': 'ifusillo@outlook.com'},
#  {'backer_id': 'ls716',
#   'cf_id': 968,
#   'name': 'Lilas Suarez',
#   'email': 'lsuarez@yandex.com'},
#  {'backer_id': 'bh265',
#   'cf_id': 65,
#   'name': 'Beatrice Huffman',
#   'email': 'bhuffman@protonmail.com'},
#  {'backer_id': 'bb194',
#   'cf_id': 968,
#   'name': 'Bart Buhr',
#   'email': 'bbuhr@yahoo.com'},
#  {'backer_id': 'sa754',
#   'cf_id': 65,
#   'name': 'Sylvester Arnould',
#   'email': 'sarnould@gmail.com'},
#  {'backer_id': 'jb318',
#   'cf_id': 563,
#   'name': 'Joseph Berardinelli',
#   'email': 'jberardinelli@protonmail.com'},
#  {'backer_id': 'ls852',
#   'cf_id': 65,
#   'name': 'Lucca Stafford',
#   'email': 'lstafford@yandex.com'},
#  {'backer_id': 'mf855',
#   'cf_id': 968,
#   'name': 'Malvina Faerber',
#   'email': 'mfaerber@gmail.com'},
#  {'backer_id': 'sg584',
#   'cf_id': 1572,
#   'name': 'Sydney Guillard',
#   'email': 'sguillard@gmail.com'},
#  {'backer_id': 'jg665',
#   'cf_id': 238,
#   'name': 'Julie Garavaglia',
#   'email': 'jgaravaglia@yandex.com'},
#  {'backer_id': 'ra144',
#   'cf_id': 948,
#   'name': 'Raeann Atkins',
#   'email': 'ratkins@protonmail.com'},
#  {'backer_id': 'ad490',
#   'cf_id': 1572,
#   'name': 'Azucena Dresdner',
#   'email': 'adresdner@yandex.com'},
#  {'backer_id': 'ab679',
#   'cf_id': 65,
#   'name': 'Aminata Bonato',
#   'email': 'abonato@protonmail.com'},
#  {'backer_id': 'mm395',
#   'cf_id': 1572,
#   'name': 'Mariya Mays',
#   'email': 'mmays@gmail.com'},
#  {'backer_id': 'tp337',
#   'cf_id': 968,
#   'name': 'Trevor Prince',
#   'email': 'tprince@yahoo.com'},
#  {'backer_id': 'li108',
#   'cf_id': 563,
#   'name': 'Lamont Ingersleben',
#   'email': 'lingersleben@yandex.com'},
#  {'backer_id': 'mb156',
#   'cf_id': 65,
#   'name': 'Mirco Boisson',
#   'email': 'mboisson@protonmail.com'},
#  {'backer_id': 'jc698',
#   'cf_id': 1572,
#   'name': 'Jessica Camilli',
#   'email': 'jcamilli@protonmail.com'},
#  {'backer_id': 'rm314',
#   'cf_id': 65,
#   'name': 'Rodrigo Meadows',
#   'email': 'rmeadows@live.com'},
#  {'backer_id': 'bm559',
#   'cf_id': 563,
#   'name': 'Barrett Mcclain',
#   'email': 'bmcclain@yahoo.com'},
#  {'backer_id': 'rj697',
#   'cf_id': 1572,
#   'name': 'Rainer Jourdain',
#   'email': 'rjourdain@yahoo.com'},
#  {'backer_id': 'eu931',
#   'cf_id': 563,
#   'name': 'Edda Underwood',
#   'email': 'eunderwood@live.com'},
#  {'backer_id': 'tf166',
#   'cf_id': 65,
#   'name': 'Tad Fleming',
#   'email': 'tfleming@yandex.com'},
#  {'backer_id': 'lb900',
#   'cf_id': 65,
#   'name': 'Lindsey Beck',
#   'email': 'lbeck@live.com'},
#  {'backer_id': 'kp905',
#   'cf_id': 1572,
#   'name': 'Kirsten Poisson',
#   'email': 'kpoisson@yahoo.com'},
#  {'backer_id': 'bm614',
#   'cf_id': 65,
#   'name': 'Barney Morris',
#   'email': 'bmorris@protonmail.com'},
#  {'backer_id': 'km622',
#   'cf_id': 65,
#   'name': 'Kasi Merritt',
#   'email': 'kmerritt@live.com'},
#  {'backer_id': 'bw202',
#   'cf_id': 1572,
#   'name': 'Brunhilde Walter',
#   'email': 'bwalter@gmail.com'},
#  {'backer_id': 'lb585',
#   'cf_id': 1572,
#   'name': 'Lilly Billet',
#   'email': 'lbillet@gmail.com'},
#  {'backer_id': 'ah247',
#   'cf_id': 1572,
#   'name': 'Alfonzo Harris',
#   'email': 'aharris@yahoo.com'},
#  {'backer_id': 'db600',
#   'cf_id': 1114,
#   'name': 'Dorine Barrett',
#   'email': 'dbarrett@gmail.com'},
#  {'backer_id': 'sb809',
#   'cf_id': 65,
#   'name': 'Soraya Boudet',
#   'email': 'sboudet@protonmail.com'},
#  {'backer_id': 'gm424',
#   'cf_id': 563,
#   'name': 'Giambattista Mazzoni',
#   'email': 'gmazzoni@gmail.com'},
#  {'backer_id': 'ch866',
#   'cf_id': 65,
# ...
#  {'backer_id': 'iv865',
#   'cf_id': 65,
#   'name': 'Immaculata Vanni',
#   'email': 'ivanni@yandex.com'},
#  {'backer_id': 'kr139',
#   'cf_id': 563,
#   'name': 'Kathern Raymond',
#   'email': 'kraymond@live.com'},
#  {'backer_id': 'kp261',
#   'cf_id': 65,
#   'name': 'Kathyrn Peck',
#   'email': 'kpeck@live.com'},
#  {'backer_id': 'hb804',
#   'cf_id': 65,
#   'name': 'Hilda Blumstein',
#   'email': 'hblumstein@protonmail.com'},
#  {'backer_id': 'mb384',
#   'cf_id': 968,
#   'name': 'Massima Baldocchi',
#   'email': 'mbaldocchi@protonmail.com'},
#  {'backer_id': 'lp884',
#   'cf_id': 1572,
#   'name': 'Lera Pearson',
#   'email': 'lpearson@protonmail.com'},
#  {'backer_id': 'ae594',
#   'cf_id': 65,
#   'name': 'Alleen Ellison',
#   'email': 'aellison@live.com'},
#  {'backer_id': 'ta987',
#   'cf_id': 1572,
#   'name': 'Tobias Althaus',
#   'email': 'talthaus@outlook.com'},
#  {'backer_id': 'kd374',
#   'cf_id': 65,
#   'name': 'Kim Desbiens',
#   'email': 'kdesbiens@yahoo.com'},
#  {'backer_id': 'lt755',
#   'cf_id': 65,
#   'name': 'Lucy Tringale',
#   'email': 'ltringale@gmail.com'},
#  {'backer_id': 'ds585',
#   'cf_id': 563,
#   'name': 'Dusti Sampson',
#   'email': 'dsampson@outlook.com'},
#  {'backer_id': 'hm748',
#   'cf_id': 238,
#   'name': 'Hyon Mcgowan',
#   'email': 'hmcgowan@outlook.com'},
#  {'backer_id': 'bm320',
#   'cf_id': 65,
#   'name': 'Benedikt Martin',
#   'email': 'bmartin@outlook.com'},
#  {'backer_id': 'mm149',
#   'cf_id': 65,
#   'name': 'Melina Montminy',
#   'email': 'mmontminy@yandex.com'},
#  {'backer_id': 'nb639',
#   'cf_id': 65,
#   'name': 'Nerezza Bottino',
#   'email': 'nbottino@yandex.com'},
#  {'backer_id': 'cw520',
#   'cf_id': 1572,
#   'name': 'Carter Washington',
#   'email': 'cwashington@yahoo.com'},
#  {'backer_id': 'lb450',
#   'cf_id': 65,
#   'name': 'Lashawnda Bradshaw',
#   'email': 'lbradshaw@yandex.com'},
#  {'backer_id': 'ap187',
#   'cf_id': 1114,
#   'name': 'Aldo Pohl',
#   'email': 'apohl@yandex.com'},
#  {'backer_id': 'gt421',
#   'cf_id': 968,
#   'name': 'Gaston Terrier',
#   'email': 'gterrier@protonmail.com'},
#  {'backer_id': 'ep895',
#   'cf_id': 968,
#   'name': 'Enric Pittman',
#   'email': 'epittman@live.com'},
#  {'backer_id': 'wa701',
#   'cf_id': 1572,
#   'name': 'Wonda Ayers',
#   'email': 'wayers@yahoo.com'},
#  {'backer_id': 'yf490',
#   'cf_id': 1114,
#   'name': 'Yasuko Fabel',
#   'email': 'yfabel@yandex.com'},
#  {'backer_id': 'fl110',
#   'cf_id': 65,
#   'name': 'Fredrik Lacroix',
#   'email': 'flacroix@live.com'},
#  {'backer_id': 'lb870',
#   'cf_id': 1114,
#   'name': 'Lucia Borgo',
#   'email': 'lborgo@protonmail.com'},
#  {'backer_id': 'dg363',
#   'cf_id': 65,
#   'name': 'Donatello Gordon',
#   'email': 'dgordon@protonmail.com'},
#  {'backer_id': 'kb110',
#   'cf_id': 1572,
#   'name': 'Kraig Busch',
#   'email': 'kbusch@live.com'},
#  {'backer_id': 'fb424',
#   'cf_id': 65,
#   'name': 'Fiona Brando',
#   'email': 'fbrando@protonmail.com'},
#  {'backer_id': 'lw574',
#   'cf_id': 65,
#   'name': 'Lisle Weaver',
#   'email': 'lweaver@live.com'},
#  {'backer_id': 'ae918',
#   'cf_id': 1114,
#   'name': 'Alec Ebner',
#   'email': 'aebner@yahoo.com'},
#  {'backer_id': 'ar961',
#   'cf_id': 968,
#   'name': 'Andreas Rigal',
#   'email': 'arigal@yahoo.com'},
#  {'backer_id': 'mt716',
#   'cf_id': 563,
#   'name': 'Malone Trani',
#   'email': 'mtrani@gmail.com'},
#  {'backer_id': 'dk254',
#   'cf_id': 968,
#   'name': 'Daniela Kirkland',
#   'email': 'dkirkland@outlook.com'},
#  {'backer_id': 'am874',
#   'cf_id': 65,
#   'name': 'Avril Mcintosh',
#   'email': 'amcintosh@protonmail.com'},
#  {'backer_id': 'cr525',
#   'cf_id': 948,
#   'name': 'Clotilde Rodrigue',
#   'email': 'crodrigue@live.com'},
#  {'backer_id': 'wc513',
#   'cf_id': 65,
#   'name': 'Wernher Carboni',
#   'email': 'wcarboni@yandex.com'},
#  {'backer_id': 'bc364',
#   'cf_id': 563,
#   'name': 'Bruna Clements',
#   'email': 'bclements@outlook.com'},
#  {'backer_id': 'cf230',
#   'cf_id': 65,
#   'name': 'Cody Feldt',
#   'email': 'cfeldt@yandex.com'},
#  {'backer_id': 'jn670',
#   'cf_id': 563,
#   'name': 'Junita Neveu',
#   'email': 'jneveu@outlook.com'},
#  {'backer_id': 'bg581',
#   'cf_id': 65,
#   'name': 'Barbara Gagliano',
#   'email': 'bgagliano@live.com'},
#  {'backer_id': 'sh228',
#   'cf_id': 1114,
#   'name': 'Sherice Hellewege',
#   'email': 'shellewege@yahoo.com'},
#  {'backer_id': 'mj954',
#   'cf_id': 65,
#   'name': 'Mitch Jalbert',
#   'email': 'mjalbert@live.com'},
#  {'backer_id': 'jm101',
#   'cf_id': 65,
#   'name': 'Johannes Magistro',
#   'email': 'jmagistro@yandex.com'},
#  {'backer_id': 'nf369',
#   'cf_id': 910,
#   'name': 'Nolann Foreman',
#   'email': 'nforeman@gmail.com'},
#  {'backer_id': 'cg631',
#   'cf_id': 65,
#   'name': 'Carline Goebel',
#   'email': 'cgoebel@yandex.com'},
#  {'backer_id': 'lp218',
#   'cf_id': 65,
#   'name': 'Livia Phaneuf',
#   'email': 'lphaneuf@outlook.com'},
#  {'backer_id': 'of784',
#   'cf_id': 65,
#   'name': 'Ottomar Foto',
#   'email': 'ofoto@yandex.com'},
#  {'backer_id': 'ds610',
#   'cf_id': 65,
#   'name': 'Deangela Schmidt',
#   'email': 'dschmidt@gmail.com'},
#  {'backer_id': 'bb467',
#   'cf_id': 1572,
#   'name': 'Bryant Borchard',
#   'email': 'bborchard@yahoo.com'},
#  {'backer_id': 'bv607',
#   'cf_id': 1114,
#   'name': 'Beatrix Vietti',
#   'email': 'bvietti@gmail.com'},
#  {'backer_id': 'cp794',
#   'cf_id': 968,
#   'name': 'Chaima Porter',
#   'email': 'cporter@gmail.com'},
#  {'backer_id': 'aw326',
#   'cf_id': 65,
#   'name': 'Armani Wheeler',
#   'email': 'awheeler@yahoo.com'},
#  {'backer_id': 'ms559',
#   'cf_id': 65,
#   'name': 'Min Schmidt',
#   'email': 'mschmidt@yandex.com'},
#  {'backer_id': 'rl122',
#   'cf_id': 563,
#   'name': 'Randal Lacasse',
#   'email': 'rlacasse@yahoo.com'},
#  {'backer_id': 'mc544',
#   'cf_id': 65,
#   'name': 'Maya Cira',
#   'email': 'mcira@yandex.com'},
#  {'backer_id': 'mv762',
#   'cf_id': 1114,
#   'name': 'Milan Valencia',
#   'email': 'mvalencia@outlook.com'},
#  {'backer_id': 'rg638',
#   'cf_id': 1114,
#   'name': 'Rosa Glover',
#   'email': 'rglover@yandex.com'},
#  {'backer_id': 'eb865',
#   'cf_id': 1114,
#   'name': 'Erich Braun',
#   'email': 'ebraun@yandex.com'},
#  {'backer_id': 'eb701',
#   'cf_id': 948,
#   'name': 'Eusebio Barthelemy',
#   'email': 'ebarthelemy@outlook.com'},
#  {'backer_id': 'lb178',
#   'cf_id': 238,
#   'name': 'Lara Buonopane',
#   'email': 'lbuonopane@outlook.com'},
#  {'backer_id': 'aa484',
#   'cf_id': 65,
#   'name': 'Anonciada Aguilar',
#   'email': 'aaguilar@yandex.com'},
#  {'backer_id': 'sh493',
#   'cf_id': 1114,
#   'name': 'Soraya Hudson',
#   'email': 'shudson@gmail.com'},
#  {'backer_id': 'rg624',
#   'cf_id': 65,
#   'name': 'Renda Gorman',
#   'email': 'rgorman@outlook.com'},
#  {'backer_id': 'am644',
#   'cf_id': 65,
#   'name': 'Anton Munier',
#   'email': 'amunier@yandex.com'},
#  {'backer_id': 'ka406',
#   'cf_id': 1572,
#   'name': 'Kiara Angelillo',
#   'email': 'kangelillo@protonmail.com'},
#  {'backer_id': 'lb213',
#   'cf_id': 65,
#   'name': 'Lucilla Black',
#   'email': 'lblack@outlook.com'},
#  {'backer_id': 'wh558',
#   'cf_id': 65,
#   'name': 'Willian Hoover',
#   'email': 'whoover@yahoo.com'},
#  {'backer_id': 'jo527',
#   'cf_id': 1572,
#   'name': 'Jenine Otto',
#   'email': 'jotto@live.com'},
#  {'backer_id': 'hd242',
#   'cf_id': 65,
#   'name': 'Helga Dupre',
#   'email': 'hdupre@live.com'},
#  {'backer_id': 'dc144',
#   'cf_id': 1114,
#   'name': 'Dorotea Cox',
#   'email': 'dcox@outlook.com'},
#  {'backer_id': 'gh229',
#   'cf_id': 968,
#   'name': 'Gonzalo Hansen',
#   'email': 'ghansen@outlook.com'},
#  {'backer_id': 'ra187',
#   'cf_id': 1572,
#   'name': 'Randell Abt',
#   'email': 'rabt@outlook.com'},
#  {'backer_id': 'lg556',
#   'cf_id': 563,
#   'name': 'Leni Grimard',
#   'email': 'lgrimard@gmail.com'},
#  {'backer_id': 'fh102',
#   'cf_id': 65,
#   'name': 'Fiammetta Huber',
#   'email': 'fhuber@outlook.com'},
#  {'backer_id': 'lh128',
#   'cf_id': 968,
#   'name': 'Larae Hildebrand',
#   'email': 'lhildebrand@outlook.com'},
#  {'backer_id': 'ah861',
#   'cf_id': 968,
#   'name': 'Annita Herve',
#   'email': 'aherve@yandex.com'},
#  {'backer_id': 'ht719',
#   'cf_id': 968,
#   'name': 'Holger Tangredi',
#   'email': 'htangredi@yandex.com'},
#  {'backer_id': 'll609',
#   'cf_id': 1572,
#   'name': 'Lionel Langley',
#   'email': 'llangley@yandex.com'},
#  {'backer_id': 'vr608',
#   'cf_id': 65,
#   'name': 'Venezio Ramos',
#   'email': 'vramos@yandex.com'},
#  {'backer_id': 'dd769',
#   'cf_id': 1911,
#   'name': 'Desmond Dreschner',
#   'email': 'ddreschner@protonmail.com'},
#  {'backer_id': 'cv209',
#   'cf_id': 1572,
#   'name': 'Casey Villard',
#   'email': 'cvillard@yandex.com'},
#  {'backer_id': 'fm638',
#   'cf_id': 1114,
#   'name': 'Felizitas Morano',
#   'email': 'fmorano@yahoo.com'},
#  {'backer_id': 'aj578',
#   'cf_id': 65,
#   'name': 'Albane Jarvis',
#   'email': 'ajarvis@protonmail.com'},
#  {'backer_id': 'ps285',
#   'cf_id': 65,
#   'name': 'Paulita Salas',
#   'email': 'psalas@outlook.com'},
#  {'backer_id': 'db210',
#   'cf_id': 65,
#   'name': 'Delbert Baffa',
#   'email': 'dbaffa@outlook.com'},
#  {'backer_id': 'au377',
#   'cf_id': 2882,
#   'name': 'Amy Underwood',
#   'email': 'aunderwood@yandex.com'},
#  {'backer_id': 'cg265',
#   'cf_id': 1572,
#   'name': 'Cristiana Griffith',
#   'email': 'cgriffith@gmail.com'},
#  {'backer_id': 'ds180',
#   'cf_id': 968,
#   'name': 'Doyle Schmid',
#   'email': 'dschmid@live.com'},
#  {'backer_id': 'rt281',
#   'cf_id': 1114,
#   'name': 'Reita Tomasso',
#   'email': 'rtomasso@yahoo.com'},
#  {'backer_id': 'ph749',
#   'cf_id': 1572,
#   'name': 'Patrizia Hinton',
#   'email': 'phinton@live.com'},
#  {'backer_id': 'tc503',
#   'cf_id': 968,
#   'name': 'Tatiana Castillo',
#   'email': 'tcastillo@yahoo.com'},
#  {'backer_id': 'mb313',
#   'cf_id': 1572,
#   'name': 'Montrel Beckert',
#   'email': 'mbeckert@yandex.com'},
#  {'backer_id': 'sl362',
#   'cf_id': 563,
#   'name': 'Shawanda Lindsey',
#   'email': 'slindsey@gmail.com'},
#  {'backer_id': 'uh381',
#   'cf_id': 968,
#   'name': 'Ulbrecht Holland',
#   'email': 'uholland@live.com'},
#  {'backer_id': 'km314',
#   'cf_id': 65,
#   'name': 'Kara Marchitelli',
#   'email': 'kmarchitelli@yandex.com'},
#  {'backer_id': 'eb969',
#   'cf_id': 1114,
#   'name': 'Else Beck',
#   'email': 'ebeck@protonmail.com'},
#  {'backer_id': 'tb251',
#   'cf_id': 1572,
#   'name': 'Tod Byrd',
#   'email': 'tbyrd@protonmail.com'},
#  {'backer_id': 'ld647',
#   'cf_id': 65,
#   'name': 'Liselotte Dittmar',
#   'email': 'ldittmar@yandex.com'},
#  {'backer_id': 'rl209',
#   'cf_id': 65,
#   'name': 'Roque Lacoste',
#   'email': 'rlacoste@live.com'},
#  {'backer_id': 'mt873',
#   'cf_id': 65,
#   'name': 'Maynard Townsend',
#   'email': 'mtownsend@yahoo.com'},
#  {'backer_id': 'lf516',
#   'cf_id': 1572,
#   'name': 'Lucie Frost',
#   'email': 'lfrost@yahoo.com'},
#  {'backer_id': 'ta679',
#   'cf_id': 65,
#   'name': 'Tristan Acker',
#   'email': 'tacker@gmail.com'},
#  {'backer_id': 'sd882',
#   'cf_id': 968,
#   'name': 'Santo Drolet',
#   'email': 'sdrolet@outlook.com'},
#  {'backer_id': 'dp941',
#   'cf_id': 968,
#   'name': 'Dewayne Pasqual',
#   'email': 'dpasqual@live.com'},
#  {'backer_id': 'ms270',
#   'cf_id': 65,
#   'name': 'Maximino Small',
#   'email': 'msmall@yahoo.com'},
#  {'backer_id': 'jf193',
#   'cf_id': 65,
#   'name': 'Jonathan Faerber',
#   'email': 'jfaerber@yahoo.com'},
#  {'backer_id': 'db832',
#   'cf_id': 65,
#   'name': 'Desmond Beauchamp',
#   'email': 'dbeauchamp@protonmail.com'},
#  {'backer_id': 'lc293',
#   'cf_id': 65,
#   'name': 'Laura Cassone',
#   'email': 'lcassone@yahoo.com'},
#  {'backer_id': 'sc440',
#   'cf_id': 563,
#   'name': 'Suzi Chen',
#   'email': 'schen@protonmail.com'},
#  {'backer_id': 'na467',
#   'cf_id': 1911,
#   'name': 'Norbert Avella',
#   'email': 'navella@yahoo.com'},
#  {'backer_id': 'mp998',
#   'cf_id': 65,
#   'name': 'Milo Porter',
#   'email': 'mporter@gmail.com'},
#  {'backer_id': 'rw179',
#   'cf_id': 1572,
#   'name': 'Rainieri Ware',
#   'email': 'rware@yahoo.com'},
#  {'backer_id': 'rd613',
#   'cf_id': 1572,
#   'name': 'Rudolph Dresdner',
#   'email': 'rdresdner@outlook.com'},
#  {'backer_id': 'dc677',
#   'cf_id': 65,
#   'name': 'Dierk Costanzo',
#   'email': 'dcostanzo@yahoo.com'},
#  {'backer_id': 'km838',
#   'cf_id': 563,
#   'name': 'Kayla Mueller',
#   'email': 'kmueller@live.com'},
#  {'backer_id': 'ha922',
#   'cf_id': 65,
#   'name': 'Heriberto Ahlers',
#   'email': 'hahlers@protonmail.com'},
#  {'backer_id': 'ma291',
#   'cf_id': 968,
#   'name': 'Marceline Albert',
#   'email': 'malbert@gmail.com'},
#  {'backer_id': 'ls903',
#   'cf_id': 1114,
#   'name': 'Loretto Salas',
#   'email': 'lsalas@yandex.com'},
#  {'backer_id': 'dl984',
#   'cf_id': 65,
#   'name': 'Delila Lawrence',
#   'email': 'dlawrence@gmail.com'},
#  {'backer_id': 'fj308',
#   'cf_id': 563,
#   'name': 'Federico Jager',
#   'email': 'fjager@live.com'},
#  {'backer_id': 'pf542',
#   'cf_id': 968,
#   'name': 'Peter Fauteux',
#   'email': 'pfauteux@yahoo.com'},
#  {'backer_id': 'mc619',
#   'cf_id': 1572,
#   'name': 'Marvin Calandra',
#   'email': 'mcalandra@yandex.com'},
#  {'backer_id': 'lc435',
#   'cf_id': 65,
#   'name': 'Lucca Crosby',
#   'email': 'lcrosby@gmail.com'},
#  {'backer_id': 'kr813',
#   'cf_id': 65,
#   'name': 'Keena Rollins',
#   'email': 'krollins@yandex.com'},
#  {'backer_id': 'eb667',
#   'cf_id': 65,
#   'name': 'Edmund Baumann',
#   'email': 'ebaumann@yandex.com'},
#  {'backer_id': 'sc261',
#   'cf_id': 65,
#   'name': 'Sara Charbonneau',
#   'email': 'scharbonneau@protonmail.com'},
#  {'backer_id': 'ht501',
#   'cf_id': 65,
#   'name': 'Hortense Tangredi',
#   'email': 'htangredi@protonmail.com'},
#  {'backer_id': 'cf209',
#   'cf_id': 1572,
#   'name': 'Constanza Frost',
#   'email': 'cfrost@yahoo.com'},
#  {'backer_id': 'th306',
#   'cf_id': 65,
#   'name': 'Tanna Henson',
#   'email': 'thenson@yandex.com'},
#  {'backer_id': 'uf135',
#   'cf_id': 1572,
#   'name': 'Ute Favreau',
#   'email': 'ufavreau@yahoo.com'},
#  {'backer_id': 'tt696',
#   'cf_id': 65,
#   'name': 'Timeo Troncone',
#   'email': 'ttroncone@live.com'},
#  {'backer_id': 'mr372',
#   'cf_id': 65,
#   'name': 'Montrel Ruiz',
#   'email': 'mruiz@protonmail.com'},
#  {'backer_id': 'lb930',
#   'cf_id': 65,
#   'name': 'Lashaunda Battle',
#   'email': 'lbattle@outlook.com'},
#  {'backer_id': 'ap347',
#   'cf_id': 65,
#   'name': 'Alger Provencher',
#   'email': 'aprovencher@yandex.com'},
#  {'backer_id': 'tb394',
#   'cf_id': 65,
#   'name': 'Teofilo Briggs',
#   'email': 'tbriggs@protonmail.com'},
#  {'backer_id': 'rn232',
#   'cf_id': 65,
#   'name': 'Rosia Newman',
#   'email': 'rnewman@protonmail.com'},
#  {'backer_id': 'df983',
#   'cf_id': 563,
#   'name': 'Dewitt Fleischer',
#   'email': 'dfleischer@protonmail.com'},
#  {'backer_id': 'ld418',
#   'cf_id': 563,
#   'name': 'Liselotte Desrochers',
#   'email': 'ldesrochers@outlook.com'},
#  {'backer_id': 'yv730',
#   'cf_id': 65,
#   'name': 'Yasmine Vitulli',
#   'email': 'yvitulli@gmail.com'},
#  {'backer_id': 'ea712',
#   'cf_id': 563,
#   'name': 'Edda Alexander',
#   'email': 'ealexander@outlook.com'},
#  {'backer_id': 'ky770',
#   'cf_id': 65,
#   'name': 'Kim Young',
#   'email': 'kyoung@yahoo.com'},
#  {'backer_id': 'jc963',
#   'cf_id': 1114,
#   'name': 'Joyce Cilento',
#   'email': 'jcilento@protonmail.com'},
#  {'backer_id': 'la958',
#   'cf_id': 65,
#   'name': 'Luca Arnold',
#   'email': 'larnold@outlook.com'},
#  {'backer_id': 'yg885',
#   'cf_id': 65,
#   'name': 'Yacine Gulla',
#   'email': 'ygulla@outlook.com'},
#  {'backer_id': 'ah815',
#   'cf_id': 65,
#   'name': 'Aemilio Hill',
#   'email': 'ahill@protonmail.com'},
#  {'backer_id': 'cm949',
#   'cf_id': 65,
#   'name': 'Carmelia Mayo',
#   'email': 'cmayo@yandex.com'},
#  {'backer_id': 'dt412',
#   'cf_id': 65,
#   'name': 'Dorothea Thompson',
#   'email': 'dthompson@live.com'},
#  {'backer_id': 'zm103',
#   'cf_id': 65,
#   'name': 'Zelie Moroni',
#   'email': 'zmoroni@outlook.com'},
#  {'backer_id': 'yh430',
#   'cf_id': 1114,
#   'name': 'Yuette Hines',
#   'email': 'yhines@protonmail.com'},
#  {'backer_id': 'sb943',
#   'cf_id': 65,
#   'name': 'Sergio Bambach',
#   'email': 'sbambach@outlook.com'},
#  {'backer_id': 'ot297',
#   'cf_id': 65,
#   'name': 'Otis Trottier',
#   'email': 'otrottier@outlook.com'},
#  {'backer_id': 'en876',
#   'cf_id': 968,
#   'name': 'Elnora Naclerio',
#   'email': 'enaclerio@live.com'},
#  {'backer_id': 'lp640',
#   'cf_id': 65,
#   'name': 'Lashell Pope',
#   'email': 'lpope@outlook.com'},
#  {'backer_id': 'es903',
#   'cf_id': 563,
#   'name': 'Emilie Schulze',
#   'email': 'eschulze@outlook.com'},
#  {'backer_id': 'nr568',
#   'cf_id': 968,
#   'name': 'Noel Rocher',
#   'email': 'nrocher@outlook.com'},
#  {'backer_id': 'nb860',
#   'cf_id': 1572,
#   'name': 'Nario Barretto',
#   'email': 'nbarretto@outlook.com'},
#  {'backer_id': 'hb501',
#   'cf_id': 65,
#   'name': 'Heidy Beasley',
#   'email': 'hbeasley@live.com'},
#  ...]

# %%
# Create a backers_df DataFrame with the following columns: 'backer_id','cf_id', 'name', and 'email' 
# using the list of values lists. 

#pass in the list of dictionaries to make a dataframe
backer_df = pd.DataFrame(backers_rows)

#print the dataframe and info
#backer_df.info() #backer_id, name, email all strings. cf_id is integer
backer_df
# Out:
#      backer_id  cf_id              name                  email
# 0        av166    968    Angelo Vincent      avincent@live.com
# 1        ha127    563     Hubert Arnold     harnold@yandex.com
# 2        lg794     65      Loris Goulet     lgoulet@yandex.com
# 3        tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4        lh506    563        Lexie Hunt         lhunt@live.com
# ...        ...    ...               ...                    ...
# 8170     st581     65   Serita Thebault   sthebault@yandex.com
# 8171     gf637    563   Glenn Foerstner   gfoerstner@yahoo.com
# 8172     rc983   1114       Robt Collin    rcollin@outlook.com
# 8173     cz381     65      Corina Zappa     czappa@outlook.com
# 8174     fg535     65     Freeman Gibbs     fgibbs@outlook.com
#
# [8175 rows x 4 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_df.to_csv("backer_df.csv", index=False, encoding='utf-8')

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 2: Use regex
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Extract the "backer_id", "cf_id", "name", and "email using regular expressions."
# 3. Create a new DataFrame with the retrieved data.
# 4. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backers = pd.read_csv("backer_info.csv")
backers
# Out:
#                                                                                              backer_info
# 0           {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1           {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2             {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3     {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4                  {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# ...                                                                                                  ...
# 8170     {"backer_id": "st581", "cf_id": 65, "name": "Serita Thebault", "email": "sthebault@yandex.com"}
# 8171    {"backer_id": "gf637", "cf_id": 563, "name": "Glenn Foerstner", "email": "gfoerstner@yahoo.com"}
# 8172        {"backer_id": "rc983", "cf_id": 1114, "name": "Robt Collin", "email": "rcollin@outlook.com"}
# 8173          {"backer_id": "cz381", "cf_id": 65, "name": "Corina Zappa", "email": "czappa@outlook.com"}
# 8174         {"backer_id": "fg535", "cf_id": 65, "name": "Freeman Gibbs", "email": "fgibbs@outlook.com"}
#
# [8175 rows x 1 columns]

# %%
# Extract the alpha-numeric "backer_id" from the backer_info column using a regex expression 
# and add it as a new column called "backer_id".
backers['backer_id'] = backers['backer_info'].str.extract('\"backer_id\"\:\s+\"(\w+)\"')

#print the df
backers

#test to make sure the backer_id extracted matches the backer_id put into the df.
    #a sum of 8175 (length of df) means it worked completely
#(backers['backer_info'].str.extract('\"backer_id\"\:\s+\"(\w+)\"')[0] == backers['backer_id']).sum()
# Out:
#                                                                                              backer_info  \
# 0           {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1           {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2             {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3     {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4                  {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# ...                                                                                                  ...
# 8170     {"backer_id": "st581", "cf_id": 65, "name": "Serita Thebault", "email": "sthebault@yandex.com"}
# 8171    {"backer_id": "gf637", "cf_id": 563, "name": "Glenn Foerstner", "email": "gfoerstner@yahoo.com"}
# 8172        {"backer_id": "rc983", "cf_id": 1114, "name": "Robt Collin", "email": "rcollin@outlook.com"}
# 8173          {"backer_id": "cz381", "cf_id": 65, "name": "Corina Zappa", "email": "czappa@outlook.com"}
# 8174         {"backer_id": "fg535", "cf_id": 65, "name": "Freeman Gibbs", "email": "fgibbs@outlook.com"}
#
#                       email backer_id
# 0         avincent@live.com     av166
# 1        harnold@yandex.com     ha127
# 2        lgoulet@yandex.com     lg794
# 3     tbrunelli@outlook.com     tb566
# 4            lhunt@live.com     lh506
# ...                     ...       ...
# 8170   sthebault@yandex.com     st581
# 8171   gfoerstner@yahoo.com     gf637
# 8172    rcollin@outlook.com     rc983
# 8173     czappa@outlook.com     cz381
# 8174     fgibbs@outlook.com     fg535
#
# [8175 rows x 3 columns]

# %%
# Extract the two to four-digit "cf_id" number from the backer_info column. 
# and add it as a new column called "cf_id".
backers['cf_id'] = backers['backer_info'].str.extract('\"cf_id\"\:\s+(\d+)\W').astype(int)

#print the df
backers

#test to make sure the cf_id extracted matches the cf_id put into the df.
    #a sum of 8175 (length of df) means it worked completely
#(backers['backer_info'].str.extract('\"cf_id\"\:\s+(\d+)\W').astype(int)[0] == backers['cf_id']).sum()
# Out:
#                                                                                              backer_info  \
# 0           {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1           {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2             {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3     {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4                  {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# ...                                                                                                  ...
# 8170     {"backer_id": "st581", "cf_id": 65, "name": "Serita Thebault", "email": "sthebault@yandex.com"}
# 8171    {"backer_id": "gf637", "cf_id": 563, "name": "Glenn Foerstner", "email": "gfoerstner@yahoo.com"}
# 8172        {"backer_id": "rc983", "cf_id": 1114, "name": "Robt Collin", "email": "rcollin@outlook.com"}
# 8173          {"backer_id": "cz381", "cf_id": 65, "name": "Corina Zappa", "email": "czappa@outlook.com"}
# 8174         {"backer_id": "fg535", "cf_id": 65, "name": "Freeman Gibbs", "email": "fgibbs@outlook.com"}
#
#                       email backer_id  cf_id
# 0         avincent@live.com     av166    968
# 1        harnold@yandex.com     ha127    563
# 2        lgoulet@yandex.com     lg794     65
# 3     tbrunelli@outlook.com     tb566    563
# 4            lhunt@live.com     lh506    563
# ...                     ...       ...    ...
# 8170   sthebault@yandex.com     st581     65
# 8171   gfoerstner@yahoo.com     gf637    563
# 8172    rcollin@outlook.com     rc983   1114
# 8173     czappa@outlook.com     cz381     65
# 8174     fgibbs@outlook.com     fg535     65
#
# [8175 rows x 4 columns]

# %%
# Extract the name from the backer_info column and add it as a new column called "name".
backers['name'] = backers['backer_info'].str.extract('\"name\"\:\s+\"(\w+\s+\w+)\"')

#print the df
backers

#test to make sure the backer_id extracted matches the backer_id put into the df.
    #a sum of 8175 (length of df) means it worked completely
#(backers['backer_info'].str.extract('\"name\"\:\s+\"(\w+\s+\w+)\"')[0] == backers['name']).sum()
# Out:
#                                                                                              backer_info  \
# 0           {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1           {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2             {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3     {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4                  {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# ...                                                                                                  ...
# 8170     {"backer_id": "st581", "cf_id": 65, "name": "Serita Thebault", "email": "sthebault@yandex.com"}
# 8171    {"backer_id": "gf637", "cf_id": 563, "name": "Glenn Foerstner", "email": "gfoerstner@yahoo.com"}
# 8172        {"backer_id": "rc983", "cf_id": 1114, "name": "Robt Collin", "email": "rcollin@outlook.com"}
# 8173          {"backer_id": "cz381", "cf_id": 65, "name": "Corina Zappa", "email": "czappa@outlook.com"}
# 8174         {"backer_id": "fg535", "cf_id": 65, "name": "Freeman Gibbs", "email": "fgibbs@outlook.com"}
#
#                       email backer_id  cf_id              name
# 0         avincent@live.com     av166    968    Angelo Vincent
# 1        harnold@yandex.com     ha127    563     Hubert Arnold
# 2        lgoulet@yandex.com     lg794     65      Loris Goulet
# 3     tbrunelli@outlook.com     tb566    563  Teodora Brunelli
# 4            lhunt@live.com     lh506    563        Lexie Hunt
# ...                     ...       ...    ...               ...
# 8170   sthebault@yandex.com     st581     65   Serita Thebault
# 8171   gfoerstner@yahoo.com     gf637    563   Glenn Foerstner
# 8172    rcollin@outlook.com     rc983   1114       Robt Collin
# 8173     czappa@outlook.com     cz381     65      Corina Zappa
# 8174     fgibbs@outlook.com     fg535     65     Freeman Gibbs
#
# [8175 rows x 5 columns]

# %%
# Extract the email from the backer_info column and add it as a new column called "email".
backers['email'] = backers['backer_info'].str.extract('\"(\S+@\S+)\"\W')
#use *.str.extractall(pat).values if you do extractall since it becomes multi-indexed and .values will make it a list

#print the df
backers

#test to make sure the email extracted matches the email put into the df.
    #a sum of 8175 (length of df) means it worked completely
#(backers['backer_info'].str.extract('\"(\S+@\S+)\"\W')[0] == backers['email']).sum()
# Out:
#                                                                                              backer_info  \
# 0           {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1           {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2             {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3     {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4                  {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}
# ...                                                                                                  ...
# 8170     {"backer_id": "st581", "cf_id": 65, "name": "Serita Thebault", "email": "sthebault@yandex.com"}
# 8171    {"backer_id": "gf637", "cf_id": 563, "name": "Glenn Foerstner", "email": "gfoerstner@yahoo.com"}
# 8172        {"backer_id": "rc983", "cf_id": 1114, "name": "Robt Collin", "email": "rcollin@outlook.com"}
# 8173          {"backer_id": "cz381", "cf_id": 65, "name": "Corina Zappa", "email": "czappa@outlook.com"}
# 8174         {"backer_id": "fg535", "cf_id": 65, "name": "Freeman Gibbs", "email": "fgibbs@outlook.com"}
#
#                       email
# 0         avincent@live.com
# 1        harnold@yandex.com
# 2        lgoulet@yandex.com
# 3     tbrunelli@outlook.com
# 4            lhunt@live.com
# ...                     ...
# 8170   sthebault@yandex.com
# 8171   gfoerstner@yahoo.com
# 8172    rcollin@outlook.com
# 8173     czappa@outlook.com
# 8174     fgibbs@outlook.com
#
# [8175 rows x 2 columns]

# %%
#check backers has the right datatypes
#backers.info()

# Create a new DataFrame with the appropriate columns.
backer_df_regex = backers[["backer_id", "cf_id", "name", "email"]].copy()
backer_df_regex
# Out:
#      backer_id  cf_id              name                  email
# 0        av166    968    Angelo Vincent      avincent@live.com
# 1        ha127    563     Hubert Arnold     harnold@yandex.com
# 2        lg794     65      Loris Goulet     lgoulet@yandex.com
# 3        tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4        lh506    563        Lexie Hunt         lhunt@live.com
# ...        ...    ...               ...                    ...
# 8170     st581     65   Serita Thebault   sthebault@yandex.com
# 8171     gf637    563   Glenn Foerstner   gfoerstner@yahoo.com
# 8172     rc983   1114       Robt Collin    rcollin@outlook.com
# 8173     cz381     65      Corina Zappa     czappa@outlook.com
# 8174     fg535     65     Freeman Gibbs     fgibbs@outlook.com
#
# [8175 rows x 4 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_df_regex.to_csv("backer_df_regex.csv", index=False, encoding='utf-8')

# %%
#we can check to make sure the two methods gave the same answers

#gives an array of true-false values
backer_df == backer_df_regex 

#check sums to quick-check each column (8175 means all values are true)
(backer_df == backer_df_regex).sum()
# Out:
# backer_id    8175
# cf_id        8175
# name         8175
# email        8175
# dtype: int64

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.
backer_df.info()
#types will already be correct since we already checked that above

backer_df_clean = backer_df.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   backer_id  8175 non-null   object
#  1   cf_id      8175 non-null   int64
#  2   name       8175 non-null   object
#  3   email      8175 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 255.6+ KB

# %%
# Convert cf_id to an integer if necessary.

#not needed

# %%
# Split the "name" column into "first_name" and "last_name" columns.

#split the "name" column on the space between the first and last names
#expand = True to make them into two columns
#assign those name columns into new columns in the df
backer_df_clean[["first_name", "last_name"]] = backer_df['name'].str.split("\s", expand=True)

backer_df_clean
# Out:
#      backer_id  cf_id              name                  email first_name  \
# 0        av166    968    Angelo Vincent      avincent@live.com     Angelo
# 1        ha127    563     Hubert Arnold     harnold@yandex.com     Hubert
# 2        lg794     65      Loris Goulet     lgoulet@yandex.com      Loris
# 3        tb566    563  Teodora Brunelli  tbrunelli@outlook.com    Teodora
# 4        lh506    563        Lexie Hunt         lhunt@live.com      Lexie
# ...        ...    ...               ...                    ...        ...
# 8170     st581     65   Serita Thebault   sthebault@yandex.com     Serita
# 8171     gf637    563   Glenn Foerstner   gfoerstner@yahoo.com      Glenn
# 8172     rc983   1114       Robt Collin    rcollin@outlook.com       Robt
# 8173     cz381     65      Corina Zappa     czappa@outlook.com     Corina
# 8174     fg535     65     Freeman Gibbs     fgibbs@outlook.com    Freeman
#
#       last_name
# 0       Vincent
# 1        Arnold
# 2        Goulet
# 3      Brunelli
# 4          Hunt
# ...         ...
# 8170   Thebault
# 8171  Foerstner
# 8172     Collin
# 8173      Zappa
# 8174      Gibbs
#
# [8175 rows x 6 columns]

# %%
#  Drop the name column
backer_df_clean = backer_df_clean.drop(labels="name", axis=1)
backer_df_clean
# Out:
#      backer_id  cf_id                  email first_name  last_name
# 0        av166    968      avincent@live.com     Angelo    Vincent
# 1        ha127    563     harnold@yandex.com     Hubert     Arnold
# 2        lg794     65     lgoulet@yandex.com      Loris     Goulet
# 3        tb566    563  tbrunelli@outlook.com    Teodora   Brunelli
# 4        lh506    563         lhunt@live.com      Lexie       Hunt
# ...        ...    ...                    ...        ...        ...
# 8170     st581     65   sthebault@yandex.com     Serita   Thebault
# 8171     gf637    563   gfoerstner@yahoo.com      Glenn  Foerstner
# 8172     rc983   1114    rcollin@outlook.com       Robt     Collin
# 8173     cz381     65     czappa@outlook.com     Corina      Zappa
# 8174     fg535     65     fgibbs@outlook.com    Freeman      Gibbs
#
# [8175 rows x 5 columns]

# %%
# Reorder the columns
backer_df_clean = backer_df_clean[["backer_id", "cf_id", "first_name", "last_name", "email"]]
backer_df_clean
# Out:
#      backer_id  cf_id first_name  last_name                  email
# 0        av166    968     Angelo    Vincent      avincent@live.com
# 1        ha127    563     Hubert     Arnold     harnold@yandex.com
# 2        lg794     65      Loris     Goulet     lgoulet@yandex.com
# 3        tb566    563    Teodora   Brunelli  tbrunelli@outlook.com
# 4        lh506    563      Lexie       Hunt         lhunt@live.com
# ...        ...    ...        ...        ...                    ...
# 8170     st581     65     Serita   Thebault   sthebault@yandex.com
# 8171     gf637    563      Glenn  Foerstner   gfoerstner@yahoo.com
# 8172     rc983   1114       Robt     Collin    rcollin@outlook.com
# 8173     cz381     65     Corina      Zappa     czappa@outlook.com
# 8174     fg535     65    Freeman      Gibbs     fgibbs@outlook.com
#
# [8175 rows x 5 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
#backer_df_clean.to_csv("backer_df_clean.csv", index=False, encoding='utf-8')
backer_df_clean.to_csv("backers.csv", index=False, encoding='utf-8')
